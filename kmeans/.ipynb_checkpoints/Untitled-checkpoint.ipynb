# %%
# !pwd
# Out:
# /home/user/Documents

# %%
from IPython.display import FileLink

# D'abord compresser
import shutil
shutil.make_archive('knnVM', 'zip', '/home/user/Documents/knn')

# Créer un lien de téléchargement
FileLink('knnVM.zip')
# Out:
# /home/user/Documents/knnVM.zip
