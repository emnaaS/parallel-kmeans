# %%
# !pwd
# Out:
# /home/user/Documents

# %%
import tensorflow
print(tensorflow.__version__)
# Out:
# 2.19.1

# %%
import glob
import os
import re
import numpy as np
import pandas as pd
from tensorflow.keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import to_categorical

# %%
import sys  
sys.path.insert(0, '../home/user/Documents')

# %%
from dotenv import load_dotenv
import os

load_dotenv("/home/user/.env")
DagsHub_username = os.getenv("DagsHub_username")
DagsHub_token=os.getenv("DagsHub_token")

print(os.getenv("DagsHub_username"))
print(os.getenv("DagsHub_token"))
# Out:
# emnaaS
# ac026871943a805c04cfaa7af4cf1a0734c83779

# %%
from kmeans_data import load_image_dataset
images, labels = load_image_dataset(
    image_dir="/home/user/datasets/splits/batch_2000",
    labels_file="/home/user/datasets/trainLabels_cropped.csv",
    max_images=2000)
# Out:
# Loaded 2000 images with labels

# %%
from kmeans_data import prepare_data
images_flat, labels_flat = prepare_data(images, labels)
# Out:
# images shape (2000, 196608)
# labels shape (2000,)

# %%
import os
os.environ['MLFLOW_TRACKING_USERNAME']= DagsHub_username
os.environ["MLFLOW_TRACKING_PASSWORD"] = DagsHub_token

# %%
import dagshub
dagshub.init(repo_owner='emnaaS', repo_name='kmeans_repo', mlflow=True)
# Out:
# Accessing as emnaaS
# Initialized MLflow to track repo "emnaaS/kmeans_repo"
# Repository emnaaS/kmeans_repo initialized!

# %%
import mlflow
mlflow.set_experiment("4ème_batch")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/4c2ef0f1ff074462bd0701a6a714aaf6', creation_time=1764067801212, experiment_id='5', last_update_time=1764067801212, lifecycle_stage='active', name='4ème_batch', tags={}>

# %%
from sequential_kmeans import cust_K_Means
import os
import time
import json
import numpy as np
import mlflow
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score
import time

# Start MLflow run
with mlflow.start_run(run_name="seq"):

    # MLflow: log parameters
    mlflow.log_param("n_clusters", 3)
    mlflow.log_param("max_iter", 300)
    mlflow.log_param("num_workers", 1)
    mlflow.log_param("num_folds", 10)
    mlflow.log_param("num_images", len(images_flat))
    
    num_features = images_flat.shape[1]
    mlflow.log_param("num_features", num_features)
    tr_time = []
    for i in range(10):
        print(f"-----------------------------------------------------------------{i+1}---------------------------------------------------------------")
        seq_kmeans = cust_K_Means(3, 300)
        debut = time.time()
        seq_kmeans.fit(images_flat)
        fin = time.time()
        tr_time.append(fin-debut)
    training_time = np.mean(tr_time)
    mlflow.log_metric("avg training time", training_time)
    num_iterations = seq_kmeans.number_of_iter
    mlflow.log_metric("iterations", num_iterations)
    cluster_labels = seq_kmeans.labels_
    # Compute cluster sizes
    unique, counts = np.unique(cluster_labels, return_counts=True)
    cluster_size_dict = {int(k): int(v) for k, v in zip(unique, counts)}
    # MLflow: Log size of each cluster
    for cluster_id, size in cluster_size_dict.items():
        mlflow.log_metric(f"cluster_{cluster_id}_size", size)

    y_pred = seq_kmeans.labels_
    # Get predictions (cluster labels)
    dbi_score = davies_bouldin_score(images_flat, y_pred)
    mlflow.log_metric("davies bouldin score ", dbi_score)
    ch_score = calinski_harabasz_score(images_flat, y_pred)
    mlflow.log_metric("calinski harabasz score ", ch_score)
    score = silhouette_score(images_flat, y_pred)
    mlflow.log_metric("silhouette score ", score)
    print("\n✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.\n")
# Out:
# -----------------------------------------------------------------1---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------2---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------3---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------4---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------5---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------6---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------7---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------8---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------9---------------------------------------------------------------
# Converged after 16 iterations
# -----------------------------------------------------------------10---------------------------------------------------------------
# Converged after 16 iterations
#
# ✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.
#
# 🏃 View run seq at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/4/runs/f5362b6f6255474cb98d3fde7e6587ea
# 🧪 View experiment at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/4

# %%
from sklearn.metrics import davies_bouldin_score
y_pred = seq_kmeans.labels_
# Get predictions (cluster labels)
dbi_score = davies_bouldin_score(images_flat, y_pred)
print(f"Davies-Bouldin Index: {dbi_score:.4f}")
# Out:
# Davies-Bouldin Index: 1.5304

# %%
from sklearn.metrics import davies_bouldin_score
y_predict = kmeans.labels_
# scikit learn
dbi_score = davies_bouldin_score(images_flat, y_predict)
print(f"Davies-Bouldin Index: {dbi_score:.4f}")
# Out:
# Davies-Bouldin Index: 1.5390

# %%
from sklearn.metrics import calinski_harabasz_score
ch_score = calinski_harabasz_score(images_flat, y_pred)
print(f"Calinski-Harabasz Index: {ch_score:.4f}")
# Out:
# Calinski-Harabasz Index: 619.4527

# %%
from sklearn.metrics import calinski_harabasz_score
ch_score = calinski_harabasz_score(images_flat, y_predict)
print(f"Calinski-Harabasz Index: {ch_score:.4f}")
# Out:
# Calinski-Harabasz Index: 619.5422

# %%
from sklearn.metrics import silhouette_score

# Compute silhouette score
score = silhouette_score(images_flat, y_pred)
print(f"Silhouette Score: {score:.4f}")
# Out:
# Silhouette Score: 0.2007

# %%
from sklearn.metrics import silhouette_score

# Compute silhouette score
score = silhouette_score(images_flat, y_predict)
print(f"Silhouette Score: {score:.4f}")
# Out:
# Silhouette Score: 0.1991

# %%
from sklearn.cluster import KMeans

# X is your flattened image matrix: shape (n_samples, n_features)
k = 10  # number of clusters you want
with mlflow.start_run(run_name="scikit_learn"):

    # MLflow: log parameters
    mlflow.log_param("n_clusters", 3)
    mlflow.log_param("max_iter", 300)
    mlflow.log_param("num_workers", 1)
    mlflow.log_param("num_folds", 1)
    mlflow.log_param("num_images", len(images_flat))
    
    num_features = images_flat.shape[1]
    mlflow.log_param("num_features", num_features)
    kmeans = KMeans(n_clusters=3, max_iter=300)
    kmeans.fit(images_flat)
    
    labels = kmeans.labels_
    centroids = kmeans.cluster_centers_
    unique, counts = np.unique(labels, return_counts=True)
    cluster_size_dict = {int(k): int(v) for k, v in zip(unique, counts)}
    # MLflow: Log size of each cluster
    for cluster_id, size in cluster_size_dict.items():
        mlflow.log_metric(f"cluster_{cluster_id}_size", size)
    print("\n✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.\n")
# Out:
# ✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.
#
# 🏃 View run scikit_learn at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/4/runs/dafb4c42f0b643d1bd0c255a44dda2f7
# 🧪 View experiment at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/4

# %%
print(kmeans.tol)
# Out:
# 0.0001

# %%
# !ls ~/Documents
# Out:
#  kmeans_dask.py		     kmeans_ray.py   runinfo
#  kmeans_data.py		     mémoire	     sequential_kmeans.py
#  kmeans_multiprocessing.py   modeling.py    'testing modularisation.ipynb'
#  kmeans_parsl.py	     __pycache__     Untitled.ipynb

# %%
from kmeans_ray import K_Means_Distributed
import os
import time
import json
import numpy as np
import mlflow
import ray
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score

# Start MLflow run
with mlflow.start_run(run_name="ray12"):

    # MLflow: log parameters
    mlflow.log_param("n_clusters", 3)
    mlflow.log_param("max_iter", 300)
    mlflow.log_param("num_workers", 12)
    mlflow.log_param("num_folds", 10)
    mlflow.log_param("num_images", len(images_flat))
    
    # Ray memory configuration
    os.environ['RAY_memory_usage_threshold'] = '0.97'
    os.environ['RAY_memory_monitor_refresh_ms'] = '250'
    num_features = images_flat.shape[1]
    mlflow.log_param("num_features", num_features)

    # Shutdown previous Ray cluster if needed
    if ray.is_initialized():
        ray.shutdown()

    # Init Ray
    ray.init(num_cpus=12)
    print(ray.cluster_resources())
    ray_time =[]
    for i in range(10):
        # Train model
        kmeans_dist = K_Means_Distributed(
            n_clusters=3,
            max_iter=300,
            num_workers=12
        )
        start_time = time.time()
        kmeans_dist.fit(images_flat)
        end_time = time.time()
        ray_time.append(end_time-start_time)
    
        training_time = np.mean(ray_time)
        print(f"Training time = {training_time:.2f} seconds")

    # MLflow: log training time
    mlflow.log_metric("avg training time", training_time)

    # Retrieve results from your KMeans class
    centroids = kmeans_dist.cluster_centers_
    num_iterations = kmeans_dist.number_of_iter
    cluster_labels = kmeans_dist.labels_

    # MLflow: Log iteration count
    mlflow.log_metric("iterations", num_iterations)

    # Compute cluster sizes
    unique, counts = np.unique(cluster_labels, return_counts=True)
    cluster_size_dict = {int(k): int(v) for k, v in zip(unique, counts)}

    # MLflow: Log size of each cluster
    for cluster_id, size in cluster_size_dict.items():
        mlflow.log_metric(f"cluster_{cluster_id}_size", size)

    y_pred = kmeans_dist.labels_
    # Get predictions (cluster labels)
    dbi_score = davies_bouldin_score(images_flat, y_pred)
    mlflow.log_metric("davies bouldin score ", dbi_score)
    ch_score = calinski_harabasz_score(images_flat, y_pred)
    mlflow.log_metric("calinski harabasz score ", ch_score)
    score = silhouette_score(images_flat, y_pred)
    mlflow.log_metric("silhouette score ", score)
    print("\n✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.\n")
# Out:
# 2025-11-26 13:29:22,748	INFO worker.py:2013 -- Started a local Ray instance.
# {'memory': 13065933620.0, 'node:__internal_head__': 1.0, 'CPU': 12.0, 'node:192.168.62.206': 1.0, 'object_store_memory': 5599685836.0}
# Data splitting & Ray.put: 0.902s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=661041) Worker - Distance computation: 1.329s | Aggregation: 0.175s | Total: 1.650s
# Ray.get (collection): 2.848s
# Result aggregation: 0.019s
# Centroid update: 0.005s
# Convergence check: 0.005s | Center shift: 323.257310
#
# --- Iteration 2 ---
# (Worker pid=661041) Worker - Distance computation: 3.355s | Aggregation: 0.164s | Total: 3.857s [repeated 19x across cluster]
# Ray.get (collection): 3.840s
# Result aggregation: 0.016s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Ray.get (collection): 3.976s
# Result aggregation: 0.015s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# (Worker pid=661042) Worker - Distance computation: 3.494s | Aggregation: 0.151s | Total: 3.846s [repeated 17x across cluster]
# Ray.get (collection): 4.026s
# Result aggregation: 0.015s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Ray.get (collection): 3.882s
# Result aggregation: 0.015s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# (Worker pid=661047) Worker - Distance computation: 3.083s | Aggregation: 0.159s | Total: 3.504s [repeated 24x across cluster]
# Ray.get (collection): 3.952s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Ray.get (collection): 3.828s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# (Worker pid=661046) Worker - Distance computation: 3.120s | Aggregation: 0.143s | Total: 3.535s [repeated 24x across cluster]
# Ray.get (collection): 3.880s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Ray.get (collection): 3.885s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# (Worker pid=661046) Worker - Distance computation: 2.894s | Aggregation: 0.234s | Total: 3.416s [repeated 24x across cluster]
# Ray.get (collection): 3.816s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Ray.get (collection): 3.645s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# (Worker pid=661048) Worker - Distance computation: 3.043s | Aggregation: 0.175s | Total: 3.513s [repeated 24x across cluster]
# Ray.get (collection): 3.732s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Ray.get (collection): 3.747s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# (Worker pid=661046) Worker - Distance computation: 2.814s | Aggregation: 0.195s | Total: 3.261s [repeated 24x across cluster]
# Ray.get (collection): 3.754s
# Result aggregation: 0.015s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Ray.get (collection): 3.680s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.167428
#
# --- Iteration 16 ---
# (Worker pid=661046) Worker - Distance computation: 3.028s | Aggregation: 0.131s | Total: 3.395s [repeated 24x across cluster]
# Ray.get (collection): 3.782s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 63.727s
# Number of iterations: 16
#
# Collection times per iteration: ['2.848s', '3.840s', '3.976s', '4.026s', '3.882s', '3.952s', '3.828s', '3.880s', '3.885s', '3.816s', '3.645s', '3.732s', '3.747s', '3.754s', '3.680s', '3.782s']
# Average collection time: 3.767s
# Somme collection time: 60.275s
# Average dispatch time: 0.072s
# Average aggregation time: 0.015s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 63.74 seconds
# Data splitting & Ray.put: 0.469s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=664118) Worker - Distance computation: 2.705s | Aggregation: 0.296s | Total: 3.143s [repeated 12x across cluster]
# Ray.get (collection): 4.572s
# Result aggregation: 0.014s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.716s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=664120) Worker - Distance computation: 2.919s | Aggregation: 0.172s | Total: 3.372s [repeated 24x across cluster]
# Ray.get (collection): 3.765s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.760s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=664120) Worker - Distance computation: 2.752s | Aggregation: 0.213s | Total: 3.227s [repeated 24x across cluster]
# Ray.get (collection): 3.720s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.666s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=664119) Worker - Distance computation: 2.990s | Aggregation: 0.243s | Total: 3.502s [repeated 24x across cluster]
# Ray.get (collection): 3.622s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 3.722s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=664131) Worker - Distance computation: 2.853s | Aggregation: 0.252s | Total: 3.374s [repeated 24x across cluster]
# Ray.get (collection): 3.762s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.648s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=664110) Worker - Distance computation: 3.002s | Aggregation: 0.154s | Total: 3.414s [repeated 24x across cluster]
# Ray.get (collection): 3.695s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.688s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=664117) Worker - Distance computation: 2.768s | Aggregation: 0.337s | Total: 3.348s [repeated 24x across cluster]
# Ray.get (collection): 3.753s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.765s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=664120) Worker - Distance computation: 2.900s | Aggregation: 0.169s | Total: 3.316s [repeated 24x across cluster]
# Ray.get (collection): 3.667s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 3.665s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 62.846s
# Number of iterations: 16
#
# Collection times per iteration: ['4.572s', '3.716s', '3.765s', '3.760s', '3.720s', '3.666s', '3.622s', '3.722s', '3.762s', '3.648s', '3.695s', '3.688s', '3.753s', '3.765s', '3.667s', '3.665s']
# Average collection time: 3.761s
# Somme collection time: 60.184s
# Average dispatch time: 0.071s
# Average aggregation time: 0.013s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 63.30 seconds
# Data splitting & Ray.put: 0.310s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=667101) Worker - Distance computation: 2.766s | Aggregation: 0.169s | Total: 3.127s [repeated 24x across cluster]
# Ray.get (collection): 4.725s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.755s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=667133) Worker - Distance computation: 2.830s | Aggregation: 0.147s | Total: 3.329s [repeated 24x across cluster]
# Ray.get (collection): 3.736s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.688s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=667101) Worker - Distance computation: 2.921s | Aggregation: 0.145s | Total: 3.338s [repeated 24x across cluster]
# Ray.get (collection): 3.692s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.670s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=667101) Worker - Distance computation: 2.919s | Aggregation: 0.221s | Total: 3.395s [repeated 24x across cluster]
# Ray.get (collection): 3.555s
# Result aggregation: 0.017s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 3.627s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=667093) Worker - Distance computation: 2.821s | Aggregation: 0.279s | Total: 3.305s [repeated 24x across cluster]
# Ray.get (collection): 3.619s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.620s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=667100) Worker - Distance computation: 2.949s | Aggregation: 0.131s | Total: 3.366s [repeated 24x across cluster]
# Ray.get (collection): 3.769s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.736s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=667109) Worker - Distance computation: 2.829s | Aggregation: 0.170s | Total: 3.223s [repeated 24x across cluster]
# Ray.get (collection): 3.643s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.790s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=667109) Worker - Distance computation: 2.769s | Aggregation: 0.150s | Total: 3.216s [repeated 24x across cluster]
# Ray.get (collection): 3.595s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 3.549s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 62.417s
# Number of iterations: 16
#
# Collection times per iteration: ['4.725s', '3.755s', '3.736s', '3.688s', '3.692s', '3.670s', '3.555s', '3.627s', '3.619s', '3.620s', '3.769s', '3.736s', '3.643s', '3.790s', '3.595s', '3.549s']
# Average collection time: 3.736s
# Somme collection time: 59.769s
# Average dispatch time: 0.074s
# Average aggregation time: 0.014s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 63.01 seconds
# Data splitting & Ray.put: 0.314s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=670090) Worker - Distance computation: 2.438s | Aggregation: 0.297s | Total: 2.933s [repeated 24x across cluster]
# Ray.get (collection): 4.628s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.511s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=670075) Worker - Distance computation: 2.704s | Aggregation: 0.376s | Total: 3.330s [repeated 24x across cluster]
# Ray.get (collection): 3.732s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.663s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=670076) Worker - Distance computation: 2.826s | Aggregation: 0.189s | Total: 3.241s [repeated 24x across cluster]
# Ray.get (collection): 3.467s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.593s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=670068) Worker - Distance computation: 2.834s | Aggregation: 0.190s | Total: 3.303s [repeated 24x across cluster]
# Ray.get (collection): 3.563s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 3.651s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=670090) Worker - Distance computation: 2.479s | Aggregation: 0.225s | Total: 2.969s [repeated 24x across cluster]
# Ray.get (collection): 3.621s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.571s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=670075) Worker - Distance computation: 2.941s | Aggregation: 0.245s | Total: 3.465s [repeated 24x across cluster]
# Ray.get (collection): 3.570s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.647s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=670091) Worker - Distance computation: 2.834s | Aggregation: 0.186s | Total: 3.339s [repeated 24x across cluster]
# Ray.get (collection): 3.695s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.692s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=670068) Worker - Distance computation: 2.910s | Aggregation: 0.181s | Total: 3.322s [repeated 24x across cluster]
# Ray.get (collection): 3.637s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 3.663s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 61.541s
# Number of iterations: 16
#
# Collection times per iteration: ['4.628s', '3.511s', '3.732s', '3.663s', '3.467s', '3.593s', '3.563s', '3.651s', '3.621s', '3.571s', '3.570s', '3.647s', '3.695s', '3.692s', '3.637s', '3.663s']
# Average collection time: 3.682s
# Somme collection time: 58.904s
# Average dispatch time: 0.071s
# Average aggregation time: 0.013s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 62.65 seconds
# Data splitting & Ray.put: 0.367s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=673034) Worker - Distance computation: 2.899s | Aggregation: 0.191s | Total: 3.225s [repeated 24x across cluster]
# Ray.get (collection): 4.657s
# Result aggregation: 0.014s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.789s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=673026) Worker - Distance computation: 2.855s | Aggregation: 0.308s | Total: 3.427s [repeated 24x across cluster]
# Ray.get (collection): 3.869s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.882s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=673042) Worker - Distance computation: 2.925s | Aggregation: 0.157s | Total: 3.393s [repeated 24x across cluster]
# Ray.get (collection): 3.934s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.933s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=673033) Worker - Distance computation: 3.061s | Aggregation: 0.131s | Total: 3.505s [repeated 24x across cluster]
# Ray.get (collection): 3.982s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 3.834s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=673034) Worker - Distance computation: 3.087s | Aggregation: 0.141s | Total: 3.494s [repeated 24x across cluster]
# Ray.get (collection): 3.919s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.958s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=673026) Worker - Distance computation: 3.217s | Aggregation: 0.194s | Total: 3.757s [repeated 24x across cluster]
# Ray.get (collection): 3.837s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.741s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=673033) Worker - Distance computation: 2.931s | Aggregation: 0.246s | Total: 3.409s [repeated 24x across cluster]
# Ray.get (collection): 3.785s
# Result aggregation: 0.015s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.767s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=673049) Worker - Distance computation: 3.065s | Aggregation: 0.162s | Total: 3.542s [repeated 24x across cluster]
# Ray.get (collection): 3.794s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 3.919s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 65.292s
# Number of iterations: 16
#
# Collection times per iteration: ['4.657s', '3.789s', '3.869s', '3.882s', '3.934s', '3.933s', '3.982s', '3.834s', '3.919s', '3.958s', '3.837s', '3.741s', '3.785s', '3.767s', '3.794s', '3.919s']
# Average collection time: 3.912s
# Somme collection time: 62.599s
# Average dispatch time: 0.072s
# Average aggregation time: 0.014s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 63.18 seconds
# Data splitting & Ray.put: 0.532s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=676012) Worker - Distance computation: 2.779s | Aggregation: 0.375s | Total: 3.269s [repeated 24x across cluster]
# Ray.get (collection): 4.809s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.869s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=676012) Worker - Distance computation: 2.830s | Aggregation: 0.160s | Total: 3.350s [repeated 24x across cluster]
# Ray.get (collection): 3.855s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.953s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=676005) Worker - Distance computation: 3.002s | Aggregation: 0.166s | Total: 3.612s [repeated 24x across cluster]
# Ray.get (collection): 3.882s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.985s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=676012) Worker - Distance computation: 3.101s | Aggregation: 0.221s | Total: 3.577s [repeated 24x across cluster]
# Ray.get (collection): 3.867s
# Result aggregation: 0.017s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 3.741s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=676005) Worker - Distance computation: 3.066s | Aggregation: 0.139s | Total: 3.493s [repeated 24x across cluster]
# Ray.get (collection): 3.781s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.812s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=676013) Worker - Distance computation: 2.824s | Aggregation: 0.405s | Total: 3.501s [repeated 24x across cluster]
# Ray.get (collection): 3.936s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.958s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=676003) Worker - Distance computation: 3.071s | Aggregation: 0.332s | Total: 3.681s [repeated 24x across cluster]
# Ray.get (collection): 3.870s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 4.001s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=676012) Worker - Distance computation: 2.890s | Aggregation: 0.255s | Total: 3.395s [repeated 24x across cluster]
# Ray.get (collection): 3.957s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 3.942s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 66.187s
# Number of iterations: 16
#
# Collection times per iteration: ['4.809s', '3.869s', '3.855s', '3.953s', '3.882s', '3.985s', '3.867s', '3.741s', '3.781s', '3.812s', '3.936s', '3.958s', '3.870s', '4.001s', '3.957s', '3.942s']
# Average collection time: 3.951s
# Somme collection time: 63.219s
# Average dispatch time: 0.077s
# Average aggregation time: 0.014s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 63.68 seconds
# Data splitting & Ray.put: 0.557s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=678967) Worker - Distance computation: 2.599s | Aggregation: 0.348s | Total: 3.045s [repeated 24x across cluster]
# Ray.get (collection): 4.565s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.851s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=678984) Worker - Distance computation: 3.007s | Aggregation: 0.221s | Total: 3.547s [repeated 24x across cluster]
# Ray.get (collection): 3.910s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.832s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=678967) Worker - Distance computation: 3.057s | Aggregation: 0.162s | Total: 3.525s [repeated 24x across cluster]
# Ray.get (collection): 3.776s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.729s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=678983) Worker - Distance computation: 2.864s | Aggregation: 0.293s | Total: 3.386s [repeated 24x across cluster]
# Ray.get (collection): 3.733s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 3.856s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=678991) Worker - Distance computation: 2.963s | Aggregation: 0.157s | Total: 3.430s [repeated 24x across cluster]
# Ray.get (collection): 3.735s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.853s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=678992) Worker - Distance computation: 2.748s | Aggregation: 0.265s | Total: 3.284s [repeated 24x across cluster]
# Ray.get (collection): 3.864s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.865s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=678994) Worker - Distance computation: 2.773s | Aggregation: 0.232s | Total: 3.278s [repeated 24x across cluster]
# Ray.get (collection): 3.750s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.834s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=678994) Worker - Distance computation: 2.940s | Aggregation: 0.180s | Total: 3.404s [repeated 24x across cluster]
# Ray.get (collection): 3.784s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 3.896s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 64.767s
# Number of iterations: 16
#
# Collection times per iteration: ['4.565s', '3.851s', '3.910s', '3.832s', '3.776s', '3.729s', '3.733s', '3.856s', '3.735s', '3.853s', '3.864s', '3.865s', '3.750s', '3.834s', '3.784s', '3.896s']
# Average collection time: 3.865s
# Somme collection time: 61.833s
# Average dispatch time: 0.079s
# Average aggregation time: 0.013s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 63.84 seconds
# Data splitting & Ray.put: 0.378s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=681935) Worker - Distance computation: 3.128s | Aggregation: 0.191s | Total: 3.443s [repeated 24x across cluster]
# Ray.get (collection): 4.910s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.930s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=681966) Worker - Distance computation: 3.072s | Aggregation: 0.194s | Total: 3.604s [repeated 24x across cluster]
# Ray.get (collection): 4.034s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.989s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=681950) Worker - Distance computation: 3.032s | Aggregation: 0.364s | Total: 3.636s [repeated 24x across cluster]
# Ray.get (collection): 4.007s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.899s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=681943) Worker - Distance computation: 2.696s | Aggregation: 0.324s | Total: 3.316s [repeated 24x across cluster]
# Ray.get (collection): 3.887s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 4.044s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=681965) Worker - Distance computation: 2.869s | Aggregation: 0.233s | Total: 3.403s [repeated 24x across cluster]
# Ray.get (collection): 4.033s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.943s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=681958) Worker - Distance computation: 3.139s | Aggregation: 0.175s | Total: 3.603s [repeated 24x across cluster]
# Ray.get (collection): 3.948s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.894s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=681950) Worker - Distance computation: 3.201s | Aggregation: 0.165s | Total: 3.673s [repeated 24x across cluster]
# Ray.get (collection): 4.042s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.985s
# Result aggregation: 0.015s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=681934) Worker - Distance computation: 3.268s | Aggregation: 0.198s | Total: 3.714s [repeated 24x across cluster]
# Ray.get (collection): 4.047s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 4.132s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 67.411s
# Number of iterations: 16
#
# Collection times per iteration: ['4.910s', '3.930s', '4.034s', '3.989s', '4.007s', '3.899s', '3.887s', '4.044s', '4.033s', '3.943s', '3.948s', '3.894s', '4.042s', '3.985s', '4.047s', '4.132s']
# Average collection time: 4.045s
# Somme collection time: 64.723s
# Average dispatch time: 0.073s
# Average aggregation time: 0.014s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 64.29 seconds
# Data splitting & Ray.put: 0.396s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=684934) Worker - Distance computation: 3.160s | Aggregation: 0.157s | Total: 3.475s [repeated 24x across cluster]
# Ray.get (collection): 5.092s
# Result aggregation: 0.014s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 3.899s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=684900) Worker - Distance computation: 3.047s | Aggregation: 0.297s | Total: 3.624s [repeated 24x across cluster]
# Ray.get (collection): 3.943s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.998s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=684917) Worker - Distance computation: 3.244s | Aggregation: 0.291s | Total: 3.829s [repeated 24x across cluster]
# Ray.get (collection): 4.182s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 4.152s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=684900) Worker - Distance computation: 2.958s | Aggregation: 0.378s | Total: 3.596s [repeated 24x across cluster]
# Ray.get (collection): 4.070s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 4.042s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=684934) Worker - Distance computation: 3.004s | Aggregation: 0.270s | Total: 3.546s [repeated 24x across cluster]
# Ray.get (collection): 4.011s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 4.038s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=684900) Worker - Distance computation: 2.895s | Aggregation: 0.387s | Total: 3.536s [repeated 24x across cluster]
# Ray.get (collection): 4.109s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.980s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=684924) Worker - Distance computation: 3.133s | Aggregation: 0.335s | Total: 3.695s [repeated 24x across cluster]
# Ray.get (collection): 3.971s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.938s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=684908) Worker - Distance computation: 3.172s | Aggregation: 0.179s | Total: 3.651s [repeated 24x across cluster]
# Ray.get (collection): 3.983s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 4.078s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 68.257s
# Number of iterations: 16
#
# Collection times per iteration: ['5.092s', '3.899s', '3.943s', '3.998s', '4.182s', '4.152s', '4.070s', '4.042s', '4.011s', '4.038s', '4.109s', '3.980s', '3.971s', '3.938s', '3.983s', '4.078s']
# Average collection time: 4.093s
# Somme collection time: 65.485s
# Average dispatch time: 0.074s
# Average aggregation time: 0.014s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 64.73 seconds
# Data splitting & Ray.put: 0.460s
#
# === Training Started ===
#
# --- Iteration 1 ---
# (Worker pid=687866) Worker - Distance computation: 2.711s | Aggregation: 0.169s | Total: 3.028s [repeated 24x across cluster]
# Ray.get (collection): 4.823s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Ray.get (collection): 4.025s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# (Worker pid=687874) Worker - Distance computation: 2.805s | Aggregation: 0.269s | Total: 3.348s [repeated 24x across cluster]
# Ray.get (collection): 3.870s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Ray.get (collection): 3.957s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# (Worker pid=687874) Worker - Distance computation: 2.973s | Aggregation: 0.251s | Total: 3.569s [repeated 24x across cluster]
# Ray.get (collection): 3.904s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Ray.get (collection): 3.901s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# (Worker pid=687875) Worker - Distance computation: 2.865s | Aggregation: 0.410s | Total: 3.579s [repeated 24x across cluster]
# Ray.get (collection): 3.960s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Ray.get (collection): 3.969s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# (Worker pid=687865) Worker - Distance computation: 2.998s | Aggregation: 0.198s | Total: 3.531s [repeated 24x across cluster]
# Ray.get (collection): 4.005s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Ray.get (collection): 3.926s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# (Worker pid=687883) Worker - Distance computation: 2.770s | Aggregation: 0.246s | Total: 3.323s [repeated 24x across cluster]
# Ray.get (collection): 3.847s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Ray.get (collection): 3.799s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# (Worker pid=687875) Worker - Distance computation: 2.969s | Aggregation: 0.239s | Total: 3.475s [repeated 24x across cluster]
# Ray.get (collection): 3.853s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Ray.get (collection): 3.783s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# (Worker pid=687893) Worker - Distance computation: 2.840s | Aggregation: 0.162s | Total: 3.319s [repeated 24x across cluster]
# Ray.get (collection): 3.800s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Ray.get (collection): 3.809s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 65.890s
# Number of iterations: 16
#
# Collection times per iteration: ['4.823s', '4.025s', '3.870s', '3.957s', '3.904s', '3.901s', '3.960s', '3.969s', '4.005s', '3.926s', '3.847s', '3.799s', '3.853s', '3.783s', '3.800s', '3.809s']
# Average collection time: 3.952s
# Somme collection time: 63.232s
# Average dispatch time: 0.069s
# Average aggregation time: 0.013s
# Average centroid update time: 0.003s
# Average convergence check time: 0.003s
# Training time = 64.85 seconds
#
# ✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.
#
# 🏃 View run ray12 at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/4/runs/e57fdab0b8f24b1ebb73795d90d5c5fe
# 🧪 View experiment at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/4

# %%
ray.shutdown()

# %%
from sklearn.metrics import davies_bouldin_score
y_ray = kmeans_dist.labels_
# scikit learn
dbi_score = davies_bouldin_score(images_flat, y_ray)
print(f"Davies-Bouldin Index: {dbi_score:.4f}")
from sklearn.metrics import calinski_harabasz_score
ch_score = calinski_harabasz_score(images_flat, y_ray)
print(f"Calinski-Harabasz Index: {ch_score:.4f}")
from sklearn.metrics import silhouette_score

# Compute silhouette score
score = silhouette_score(images_flat, y_ray)
print(f"Silhouette Score: {score:.4f}")

# %%
len(ray_time)
# Out:
# 10

# %%
ray.shutdown()

# %%
import shutil
from IPython.display import FileLink

# Replace 'your_folder_name' with your actual folder path
folder_name = '/home/user/datasets/splits'

# Create ZIP archive
shutil.make_archive('splits', 'zip', folder_name)

# Generate download link
FileLink('splits.zip')
# Out:
# /home/user/Documents/splits.zip

# %%
print(images_flat.dtype)
kmeans_parsl.dtype
# Out:
# float32
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 2
#       1 print(images_flat.dtype)
# ----> 2 kmeans_parsl.dtype
#
# AttributeError: 'KMeansDistributedParsl' object has no attribute 'dtype'

# %%
parsl.clear()

# %%
from kmeans_parsl import KMeansDistributedParsl
import parsl
from parsl.app.app import python_app
from parsl.config import Config
from parsl.executors import ThreadPoolExecutor
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score

# Start MLflow run
with mlflow.start_run(run_name="parsl12"):
    # Setup Parsl configuration
    # Disable all parsl logging before loading
    import logging
    # MLflow: log parameters
    mlflow.log_param("n_clusters", 3)
    mlflow.log_param("max_iter", 300)
    mlflow.log_param("num_workers", 12)
    mlflow.log_param("num_folds", 10)
    mlflow.log_param("num_images", len(images_flat))
    num_features = images_flat.shape[1]
    mlflow.log_param("num_features", num_features)
    
    parsl.set_stream_logger(level=logging.CRITICAL)
    config = Config(
            executors=[
                    ThreadPoolExecutor(max_threads=12, label='local_threads')
             ],
        monitoring=None,  # Disable monitoring
        usage_tracking=False
        )
    parsl.load(config)
    parsl_time=[]
    for i in range(10):
        print(f'---------------------------------------{i+1}------------------------------')
        kmeans_parsl = KMeansDistributedParsl(n_clusters=3, n_workers=12)
        # Create and fit model
        import time
        debut = time.time()
        kmeans_parsl.fit(images_flat)
        fin = time.time()
        parsl_time.append(fin-debut)
    
    
    training_time = np.mean(parsl_time)
    print(f"Training time = {training_time:.2f} seconds")

    # MLflow: log training time
    mlflow.log_metric("avg training time", training_time)

    # Retrieve results from your KMeans class
    centroids = kmeans_parsl.cluster_centers_
    num_iterations = kmeans_parsl.number_of_iter
    cluster_labels = kmeans_parsl.labels_

    # MLflow: Log iteration count
    mlflow.log_metric("iterations", num_iterations)

    # Compute cluster sizes
    unique, counts = np.unique(cluster_labels, return_counts=True)
    cluster_size_dict = {int(k): int(v) for k, v in zip(unique, counts)}

    # MLflow: Log size of each cluster
    for cluster_id, size in cluster_size_dict.items():
        mlflow.log_metric(f"cluster_{cluster_id}_size", size)

    y_pred = kmeans_parsl.labels_
    # Get predictions (cluster labels)
    dbi_score = davies_bouldin_score(images_flat, y_pred)
    mlflow.log_metric("davies bouldin score ", dbi_score)
    ch_score = calinski_harabasz_score(images_flat, y_pred)
    mlflow.log_metric("calinski harabasz score ", ch_score)
    score = silhouette_score(images_flat, y_pred)
    mlflow.log_metric("silhouette score ", score)


    print("\n✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.\n")

    
    # Clean up
    parsl.clear()
# Out:
# ---------------------------------------1------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.049s
# Gather results (parallel work): 3.196s
# Result aggregation: 0.083s
# Centroid update: 0.013s
# Convergence check: 0.008s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.349s
#
# --- Iteration 2 ---
# Submit tasks: 0.045s
# Gather results (parallel work): 4.265s
# Result aggregation: 0.024s
# Centroid update: 0.005s
# Convergence check: 0.006s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.345s
#
# --- Iteration 3 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 4.284s
# Result aggregation: 0.024s
# Centroid update: 0.005s
# Convergence check: 0.004s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.349s
#
# --- Iteration 4 ---
# Submit tasks: 0.050s
# Gather results (parallel work): 4.120s
# Result aggregation: 0.025s
# Centroid update: 0.005s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.206s
#
# --- Iteration 5 ---
# Submit tasks: 0.014s
# Gather results (parallel work): 4.350s
# Result aggregation: 0.026s
# Centroid update: 0.005s
# Convergence check: 0.006s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.403s
#
# --- Iteration 6 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 4.508s
# Result aggregation: 0.028s
# Centroid update: 0.006s
# Convergence check: 0.009s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 4.591s
#
# --- Iteration 7 ---
# Submit tasks: 0.037s
# Gather results (parallel work): 4.355s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.422s
#
# --- Iteration 8 ---
# Submit tasks: 0.042s
# Gather results (parallel work): 4.373s
# Result aggregation: 0.026s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.448s
#
# --- Iteration 9 ---
# Submit tasks: 0.026s
# Gather results (parallel work): 4.619s
# Result aggregation: 0.026s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.679s
#
# --- Iteration 10 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 4.592s
# Result aggregation: 0.026s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.659s
#
# --- Iteration 11 ---
# Submit tasks: 0.044s
# Gather results (parallel work): 4.391s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.469s
#
# --- Iteration 12 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 4.279s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.343s
#
# --- Iteration 13 ---
# Submit tasks: 0.037s
# Gather results (parallel work): 4.263s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.332s
#
# --- Iteration 14 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 4.141s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.213s
#
# --- Iteration 15 ---
# Submit tasks: 0.013s
# Gather results (parallel work): 4.366s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.408s
#
# --- Iteration 16 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 4.325s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.387s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 71.229s
# Number of iterations: 16
#
# Submit times per iteration: ['0.049s', '0.045s', '0.031s', '0.050s', '0.014s', '0.038s', '0.037s', '0.042s', '0.026s', '0.034s', '0.044s', '0.034s', '0.037s', '0.039s', '0.013s', '0.032s']
# Sum submit time: 0.565s
#
# Gather times per iteration: ['3.196s', '4.265s', '4.284s', '4.120s', '4.350s', '4.508s', '4.355s', '4.373s', '4.619s', '4.592s', '4.391s', '4.279s', '4.263s', '4.141s', '4.366s', '4.325s']
# Sum gather time: 68.427s
#
# Sum aggregation time: 0.458s
# Sum centroid update time: 0.072s
# Sum convergence check time: 0.065s
# Sum iteration overhead time: 0.015s
#
# === Time Breakdown ===
# Submit tasks: 0.565s (0.8%)
# Gather (parallel work): 68.427s (98.3%)
# Aggregation: 0.458s (0.7%)
# Centroid updates: 0.072s (0.1%)
# Convergence checks: 0.065s (0.1%)
# Iteration overhead (print, misc): 0.015s (0.0%)
#
# === Verification ===
# Sum of all measured times: 69.603s
# Actual total training time: 71.229s
# Setup time: 0.000s
# Expected total: 69.603s
# ---------------------------------------2------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.017s
# Gather results (parallel work): 3.678s
# Result aggregation: 0.027s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.727s
#
# --- Iteration 2 ---
# Submit tasks: 0.043s
# Gather results (parallel work): 3.656s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.730s
#
# --- Iteration 3 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 3.681s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.742s
#
# --- Iteration 4 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 3.616s
# Result aggregation: 0.023s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.680s
#
# --- Iteration 5 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 3.656s
# Result aggregation: 0.023s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.721s
#
# --- Iteration 6 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 3.725s
# Result aggregation: 0.037s
# Centroid update: 0.005s
# Convergence check: 0.005s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.811s
#
# --- Iteration 7 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 3.638s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.704s
#
# --- Iteration 8 ---
# Submit tasks: 0.030s
# Gather results (parallel work): 3.571s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.631s
#
# --- Iteration 9 ---
# Submit tasks: 0.028s
# Gather results (parallel work): 3.580s
# Result aggregation: 0.035s
# Centroid update: 0.003s
# Convergence check: 0.008s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.656s
#
# --- Iteration 10 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 3.647s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.004s
# Total iteration time: 3.717s
#
# --- Iteration 11 ---
# Submit tasks: 0.046s
# Gather results (parallel work): 3.773s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.852s
#
# --- Iteration 12 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 3.741s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.812s
#
# --- Iteration 13 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 3.866s
# Result aggregation: 0.025s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.930s
#
# --- Iteration 14 ---
# Submit tasks: 0.040s
# Gather results (parallel work): 3.684s
# Result aggregation: 0.031s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.763s
#
# --- Iteration 15 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 3.852s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.913s
#
# --- Iteration 16 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 3.762s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.835s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 61.261s
# Number of iterations: 16
#
# Submit times per iteration: ['0.017s', '0.043s', '0.033s', '0.033s', '0.035s', '0.038s', '0.031s', '0.030s', '0.028s', '0.034s', '0.046s', '0.041s', '0.032s', '0.040s', '0.031s', '0.041s']
# Sum submit time: 0.553s
#
# Gather times per iteration: ['3.678s', '3.656s', '3.681s', '3.616s', '3.656s', '3.725s', '3.638s', '3.571s', '3.580s', '3.647s', '3.773s', '3.741s', '3.866s', '3.684s', '3.852s', '3.762s']
# Sum gather time: 59.127s
#
# Sum aggregation time: 0.420s
# Sum centroid update time: 0.052s
# Sum convergence check time: 0.054s
# Sum iteration overhead time: 0.019s
#
# === Time Breakdown ===
# Submit tasks: 0.553s (0.9%)
# Gather (parallel work): 59.127s (98.2%)
# Aggregation: 0.420s (0.7%)
# Centroid updates: 0.052s (0.1%)
# Convergence checks: 0.054s (0.1%)
# Iteration overhead (print, misc): 0.019s (0.0%)
#
# === Verification ===
# Sum of all measured times: 60.225s
# Actual total training time: 61.261s
# Setup time: 0.000s
# Expected total: 60.226s
# ---------------------------------------3------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 3.490s
# Result aggregation: 0.024s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.555s
#
# --- Iteration 2 ---
# Submit tasks: 0.042s
# Gather results (parallel work): 3.523s
# Result aggregation: 0.032s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.606s
#
# --- Iteration 3 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 3.456s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.517s
#
# --- Iteration 4 ---
# Submit tasks: 0.044s
# Gather results (parallel work): 3.545s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.623s
#
# --- Iteration 5 ---
# Submit tasks: 0.045s
# Gather results (parallel work): 3.376s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.450s
#
# --- Iteration 6 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 3.365s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.432s
#
# --- Iteration 7 ---
# Submit tasks: 0.036s
# Gather results (parallel work): 3.494s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.561s
#
# --- Iteration 8 ---
# Submit tasks: 0.036s
# Gather results (parallel work): 3.399s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.465s
#
# --- Iteration 9 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 3.439s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.500s
#
# --- Iteration 10 ---
# Submit tasks: 0.036s
# Gather results (parallel work): 3.361s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.426s
#
# --- Iteration 11 ---
# Submit tasks: 0.028s
# Gather results (parallel work): 3.305s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.365s
#
# --- Iteration 12 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 3.185s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.251s
#
# --- Iteration 13 ---
# Submit tasks: 0.051s
# Gather results (parallel work): 3.277s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.360s
#
# --- Iteration 14 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 3.427s
# Result aggregation: 0.021s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.488s
#
# --- Iteration 15 ---
# Submit tasks: 0.042s
# Gather results (parallel work): 3.597s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.671s
#
# --- Iteration 16 ---
# Submit tasks: 0.029s
# Gather results (parallel work): 3.444s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.503s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 56.570s
# Number of iterations: 16
#
# Submit times per iteration: ['0.035s', '0.042s', '0.032s', '0.044s', '0.045s', '0.038s', '0.036s', '0.036s', '0.031s', '0.036s', '0.028s', '0.034s', '0.051s', '0.034s', '0.042s', '0.029s']
# Sum submit time: 0.593s
#
# Gather times per iteration: ['3.490s', '3.523s', '3.456s', '3.545s', '3.376s', '3.365s', '3.494s', '3.399s', '3.439s', '3.361s', '3.305s', '3.185s', '3.277s', '3.427s', '3.597s', '3.444s']
# Sum gather time: 54.683s
#
# Sum aggregation time: 0.386s
# Sum centroid update time: 0.047s
# Sum convergence check time: 0.048s
# Sum iteration overhead time: 0.015s
#
# === Time Breakdown ===
# Submit tasks: 0.593s (1.1%)
# Gather (parallel work): 54.683s (98.0%)
# Aggregation: 0.386s (0.7%)
# Centroid updates: 0.047s (0.1%)
# Convergence checks: 0.048s (0.1%)
# Iteration overhead (print, misc): 0.015s (0.0%)
#
# === Verification ===
# Sum of all measured times: 55.771s
# Actual total training time: 56.570s
# Setup time: 0.000s
# Expected total: 55.771s
# ---------------------------------------4------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.042s
# Gather results (parallel work): 3.059s
# Result aggregation: 0.023s
# Centroid update: 0.002s
# Convergence check: 0.002s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.129s
#
# --- Iteration 2 ---
# Submit tasks: 0.028s
# Gather results (parallel work): 3.123s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.182s
#
# --- Iteration 3 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 3.115s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.176s
#
# --- Iteration 4 ---
# Submit tasks: 0.044s
# Gather results (parallel work): 3.081s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.155s
#
# --- Iteration 5 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 3.049s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.109s
#
# --- Iteration 6 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 3.042s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.110s
#
# --- Iteration 7 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 2.977s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.044s
#
# --- Iteration 8 ---
# Submit tasks: 0.043s
# Gather results (parallel work): 3.041s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.115s
#
# --- Iteration 9 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 2.954s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.016s
#
# --- Iteration 10 ---
# Submit tasks: 0.026s
# Gather results (parallel work): 2.990s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.046s
#
# --- Iteration 11 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 3.046s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.113s
#
# --- Iteration 12 ---
# Submit tasks: 0.030s
# Gather results (parallel work): 3.040s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.099s
#
# --- Iteration 13 ---
# Submit tasks: 0.043s
# Gather results (parallel work): 3.071s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.146s
#
# --- Iteration 14 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 3.156s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.220s
#
# --- Iteration 15 ---
# Submit tasks: 0.029s
# Gather results (parallel work): 3.131s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.191s
#
# --- Iteration 16 ---
# Submit tasks: 0.049s
# Gather results (parallel work): 3.184s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.265s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 50.942s
# Number of iterations: 16
#
# Submit times per iteration: ['0.042s', '0.028s', '0.032s', '0.044s', '0.031s', '0.038s', '0.038s', '0.043s', '0.033s', '0.026s', '0.035s', '0.030s', '0.043s', '0.035s', '0.029s', '0.049s']
# Sum submit time: 0.575s
#
# Gather times per iteration: ['3.059s', '3.123s', '3.115s', '3.081s', '3.049s', '3.042s', '2.977s', '3.041s', '2.954s', '2.990s', '3.046s', '3.040s', '3.071s', '3.156s', '3.131s', '3.184s']
# Sum gather time: 49.061s
#
# Sum aggregation time: 0.372s
# Sum centroid update time: 0.047s
# Sum convergence check time: 0.046s
# Sum iteration overhead time: 0.015s
#
# === Time Breakdown ===
# Submit tasks: 0.575s (1.1%)
# Gather (parallel work): 49.061s (97.9%)
# Aggregation: 0.372s (0.7%)
# Centroid updates: 0.047s (0.1%)
# Convergence checks: 0.046s (0.1%)
# Iteration overhead (print, misc): 0.015s (0.0%)
#
# === Verification ===
# Sum of all measured times: 50.116s
# Actual total training time: 50.942s
# Setup time: 0.000s
# Expected total: 50.116s
# ---------------------------------------5------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 2.957s
# Result aggregation: 0.025s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.027s
#
# --- Iteration 2 ---
# Submit tasks: 0.066s
# Gather results (parallel work): 3.108s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.205s
#
# --- Iteration 3 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 3.169s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.236s
#
# --- Iteration 4 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 3.284s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.356s
#
# --- Iteration 5 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 3.227s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.296s
#
# --- Iteration 6 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 3.304s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.372s
#
# --- Iteration 7 ---
# Submit tasks: 0.030s
# Gather results (parallel work): 3.220s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.279s
#
# --- Iteration 8 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 3.314s
# Result aggregation: 0.030s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.393s
#
# --- Iteration 9 ---
# Submit tasks: 0.029s
# Gather results (parallel work): 3.131s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.194s
#
# --- Iteration 10 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 3.227s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.292s
#
# --- Iteration 11 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 3.080s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.142s
#
# --- Iteration 12 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 3.205s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.279s
#
# --- Iteration 13 ---
# Submit tasks: 0.053s
# Gather results (parallel work): 3.220s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.302s
#
# --- Iteration 14 ---
# Submit tasks: 0.044s
# Gather results (parallel work): 3.141s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.220s
#
# --- Iteration 15 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 3.301s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.366s
#
# --- Iteration 16 ---
# Submit tasks: 0.045s
# Gather results (parallel work): 3.257s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.336s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 53.128s
# Number of iterations: 16
#
# Submit times per iteration: ['0.039s', '0.066s', '0.032s', '0.035s', '0.035s', '0.038s', '0.030s', '0.041s', '0.029s', '0.031s', '0.033s', '0.039s', '0.053s', '0.044s', '0.034s', '0.045s']
# Sum submit time: 0.624s
#
# Gather times per iteration: ['2.957s', '3.108s', '3.169s', '3.284s', '3.227s', '3.304s', '3.220s', '3.314s', '3.131s', '3.227s', '3.080s', '3.205s', '3.220s', '3.141s', '3.301s', '3.257s']
# Sum gather time: 51.145s
#
# Sum aggregation time: 0.413s
# Sum centroid update time: 0.048s
# Sum convergence check time: 0.048s
# Sum iteration overhead time: 0.017s
#
# === Time Breakdown ===
# Submit tasks: 0.624s (1.2%)
# Gather (parallel work): 51.145s (97.8%)
# Aggregation: 0.413s (0.8%)
# Centroid updates: 0.048s (0.1%)
# Convergence checks: 0.048s (0.1%)
# Iteration overhead (print, misc): 0.017s (0.0%)
#
# === Verification ===
# Sum of all measured times: 52.295s
# Actual total training time: 53.128s
# Setup time: 0.000s
# Expected total: 52.295s
# ---------------------------------------6------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.025s
# Gather results (parallel work): 2.932s
# Result aggregation: 0.024s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.987s
#
# --- Iteration 2 ---
# Submit tasks: 0.045s
# Gather results (parallel work): 3.088s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.161s
#
# --- Iteration 3 ---
# Submit tasks: 0.045s
# Gather results (parallel work): 3.078s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.158s
#
# --- Iteration 4 ---
# Submit tasks: 0.054s
# Gather results (parallel work): 3.173s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.258s
#
# --- Iteration 5 ---
# Submit tasks: 0.036s
# Gather results (parallel work): 3.311s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.381s
#
# --- Iteration 6 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 3.320s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.394s
#
# --- Iteration 7 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 3.263s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.339s
#
# --- Iteration 8 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 3.281s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.352s
#
# --- Iteration 9 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 3.317s
# Result aggregation: 0.029s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.394s
#
# --- Iteration 10 ---
# Submit tasks: 0.028s
# Gather results (parallel work): 3.215s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.274s
#
# --- Iteration 11 ---
# Submit tasks: 0.036s
# Gather results (parallel work): 3.276s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.344s
#
# --- Iteration 12 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 3.269s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.339s
#
# --- Iteration 13 ---
# Submit tasks: 0.047s
# Gather results (parallel work): 3.194s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.272s
#
# --- Iteration 14 ---
# Submit tasks: 0.030s
# Gather results (parallel work): 3.198s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.263s
#
# --- Iteration 15 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 3.289s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.359s
#
# --- Iteration 16 ---
# Submit tasks: 0.043s
# Gather results (parallel work): 3.103s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.179s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 53.328s
# Number of iterations: 16
#
# Submit times per iteration: ['0.025s', '0.045s', '0.045s', '0.054s', '0.036s', '0.039s', '0.041s', '0.041s', '0.041s', '0.028s', '0.036s', '0.039s', '0.047s', '0.030s', '0.039s', '0.043s']
# Sum submit time: 0.628s
#
# Gather times per iteration: ['2.932s', '3.088s', '3.078s', '3.173s', '3.311s', '3.320s', '3.263s', '3.281s', '3.317s', '3.215s', '3.276s', '3.269s', '3.194s', '3.198s', '3.289s', '3.103s']
# Sum gather time: 51.308s
#
# Sum aggregation time: 0.402s
# Sum centroid update time: 0.047s
# Sum convergence check time: 0.052s
# Sum iteration overhead time: 0.017s
#
# === Time Breakdown ===
# Submit tasks: 0.628s (1.2%)
# Gather (parallel work): 51.308s (97.8%)
# Aggregation: 0.402s (0.8%)
# Centroid updates: 0.047s (0.1%)
# Convergence checks: 0.052s (0.1%)
# Iteration overhead (print, misc): 0.017s (0.0%)
#
# === Verification ===
# Sum of all measured times: 52.454s
# Actual total training time: 53.328s
# Setup time: 0.000s
# Expected total: 52.454s
# ---------------------------------------7------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.025s
# Gather results (parallel work): 3.057s
# Result aggregation: 0.022s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.110s
#
# --- Iteration 2 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 3.057s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.124s
#
# --- Iteration 3 ---
# Submit tasks: 0.025s
# Gather results (parallel work): 2.980s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.037s
#
# --- Iteration 4 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 3.004s
# Result aggregation: 0.021s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.065s
#
# --- Iteration 5 ---
# Submit tasks: 0.037s
# Gather results (parallel work): 3.075s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.140s
#
# --- Iteration 6 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 3.066s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.139s
#
# --- Iteration 7 ---
# Submit tasks: 0.040s
# Gather results (parallel work): 2.966s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.037s
#
# --- Iteration 8 ---
# Submit tasks: 0.036s
# Gather results (parallel work): 3.066s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.134s
#
# --- Iteration 9 ---
# Submit tasks: 0.044s
# Gather results (parallel work): 3.007s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.081s
#
# --- Iteration 10 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 3.100s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.168s
#
# --- Iteration 11 ---
# Submit tasks: 0.056s
# Gather results (parallel work): 2.976s
# Result aggregation: 0.025s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.064s
#
# --- Iteration 12 ---
# Submit tasks: 0.029s
# Gather results (parallel work): 3.000s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.064s
#
# --- Iteration 13 ---
# Submit tasks: 0.030s
# Gather results (parallel work): 3.031s
# Result aggregation: 0.026s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.094s
#
# --- Iteration 14 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 3.005s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.067s
#
# --- Iteration 15 ---
# Submit tasks: 0.040s
# Gather results (parallel work): 2.970s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.040s
#
# --- Iteration 16 ---
# Submit tasks: 0.027s
# Gather results (parallel work): 3.025s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.084s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 50.263s
# Number of iterations: 16
#
# Submit times per iteration: ['0.025s', '0.038s', '0.025s', '0.033s', '0.037s', '0.041s', '0.040s', '0.036s', '0.044s', '0.035s', '0.056s', '0.029s', '0.030s', '0.033s', '0.040s', '0.027s']
# Sum submit time: 0.569s
#
# Gather times per iteration: ['3.057s', '3.057s', '2.980s', '3.004s', '3.075s', '3.066s', '2.966s', '3.066s', '3.007s', '3.100s', '2.976s', '3.000s', '3.031s', '3.005s', '2.970s', '3.025s']
# Sum gather time: 48.384s
#
# Sum aggregation time: 0.387s
# Sum centroid update time: 0.049s
# Sum convergence check time: 0.044s
# Sum iteration overhead time: 0.015s
#
# === Time Breakdown ===
# Submit tasks: 0.569s (1.2%)
# Gather (parallel work): 48.384s (97.8%)
# Aggregation: 0.387s (0.8%)
# Centroid updates: 0.049s (0.1%)
# Convergence checks: 0.044s (0.1%)
# Iteration overhead (print, misc): 0.015s (0.0%)
#
# === Verification ===
# Sum of all measured times: 49.449s
# Actual total training time: 50.263s
# Setup time: 0.000s
# Expected total: 49.449s
# ---------------------------------------8------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 2.831s
# Result aggregation: 0.022s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.891s
#
# --- Iteration 2 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 2.833s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.901s
#
# --- Iteration 3 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 2.799s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.861s
#
# --- Iteration 4 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 2.759s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.823s
#
# --- Iteration 5 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 2.828s
# Result aggregation: 0.021s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.888s
#
# --- Iteration 6 ---
# Submit tasks: 0.037s
# Gather results (parallel work): 2.784s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.850s
#
# --- Iteration 7 ---
# Submit tasks: 0.026s
# Gather results (parallel work): 2.860s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.917s
#
# --- Iteration 8 ---
# Submit tasks: 0.029s
# Gather results (parallel work): 2.857s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.916s
#
# --- Iteration 9 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 2.883s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 2.949s
#
# --- Iteration 10 ---
# Submit tasks: 0.044s
# Gather results (parallel work): 2.786s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.863s
#
# --- Iteration 11 ---
# Submit tasks: 0.045s
# Gather results (parallel work): 2.792s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.865s
#
# --- Iteration 12 ---
# Submit tasks: 0.026s
# Gather results (parallel work): 2.824s
# Result aggregation: 0.028s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.885s
#
# --- Iteration 13 ---
# Submit tasks: 0.026s
# Gather results (parallel work): 2.732s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.787s
#
# --- Iteration 14 ---
# Submit tasks: 0.022s
# Gather results (parallel work): 2.802s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.858s
#
# --- Iteration 15 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 2.832s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.898s
#
# --- Iteration 16 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 2.930s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.993s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 46.941s
# Number of iterations: 16
#
# Submit times per iteration: ['0.032s', '0.035s', '0.033s', '0.035s', '0.032s', '0.037s', '0.026s', '0.029s', '0.031s', '0.044s', '0.045s', '0.026s', '0.026s', '0.022s', '0.035s', '0.033s']
# Sum submit time: 0.522s
#
# Gather times per iteration: ['2.831s', '2.833s', '2.799s', '2.759s', '2.828s', '2.784s', '2.860s', '2.857s', '2.883s', '2.786s', '2.792s', '2.824s', '2.732s', '2.802s', '2.832s', '2.930s']
# Sum gather time: 45.133s
#
# Sum aggregation time: 0.384s
# Sum centroid update time: 0.046s
# Sum convergence check time: 0.044s
# Sum iteration overhead time: 0.016s
#
# === Time Breakdown ===
# Submit tasks: 0.522s (1.1%)
# Gather (parallel work): 45.133s (97.8%)
# Aggregation: 0.384s (0.8%)
# Centroid updates: 0.046s (0.1%)
# Convergence checks: 0.044s (0.1%)
# Iteration overhead (print, misc): 0.016s (0.0%)
#
# === Verification ===
# Sum of all measured times: 46.145s
# Actual total training time: 46.941s
# Setup time: 0.000s
# Expected total: 46.145s
# ---------------------------------------9------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 2.768s
# Result aggregation: 0.026s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.839s
#
# --- Iteration 2 ---
# Submit tasks: 0.020s
# Gather results (parallel work): 2.670s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.722s
#
# --- Iteration 3 ---
# Submit tasks: 0.038s
# Gather results (parallel work): 2.636s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.703s
#
# --- Iteration 4 ---
# Submit tasks: 0.030s
# Gather results (parallel work): 2.604s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.666s
#
# --- Iteration 5 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 2.805s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.871s
#
# --- Iteration 6 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 2.664s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.734s
#
# --- Iteration 7 ---
# Submit tasks: 0.027s
# Gather results (parallel work): 2.621s
# Result aggregation: 0.025s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.680s
#
# --- Iteration 8 ---
# Submit tasks: 0.044s
# Gather results (parallel work): 2.599s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.674s
#
# --- Iteration 9 ---
# Submit tasks: 0.025s
# Gather results (parallel work): 2.692s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.749s
#
# --- Iteration 10 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 2.739s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.799s
#
# --- Iteration 11 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 2.630s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.702s
#
# --- Iteration 12 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 2.640s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.707s
#
# --- Iteration 13 ---
# Submit tasks: 0.039s
# Gather results (parallel work): 2.649s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.720s
#
# --- Iteration 14 ---
# Submit tasks: 0.041s
# Gather results (parallel work): 2.640s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.712s
#
# --- Iteration 15 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 2.613s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.681s
#
# --- Iteration 16 ---
# Submit tasks: 0.036s
# Gather results (parallel work): 2.642s
# Result aggregation: 0.026s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.711s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 44.504s
# Number of iterations: 16
#
# Submit times per iteration: ['0.039s', '0.020s', '0.038s', '0.030s', '0.031s', '0.039s', '0.027s', '0.044s', '0.025s', '0.031s', '0.039s', '0.034s', '0.039s', '0.041s', '0.035s', '0.036s']
# Sum submit time: 0.549s
#
# Gather times per iteration: ['2.768s', '2.670s', '2.636s', '2.604s', '2.805s', '2.664s', '2.621s', '2.599s', '2.692s', '2.739s', '2.630s', '2.640s', '2.649s', '2.640s', '2.613s', '2.642s']
# Sum gather time: 42.614s
#
# Sum aggregation time: 0.404s
# Sum centroid update time: 0.049s
# Sum convergence check time: 0.043s
# Sum iteration overhead time: 0.014s
#
# === Time Breakdown ===
# Submit tasks: 0.549s (1.3%)
# Gather (parallel work): 42.614s (97.6%)
# Aggregation: 0.404s (0.9%)
# Centroid updates: 0.049s (0.1%)
# Convergence checks: 0.043s (0.1%)
# Iteration overhead (print, misc): 0.014s (0.0%)
#
# === Verification ===
# Sum of all measured times: 43.672s
# Actual total training time: 44.504s
# Setup time: 0.000s
# Expected total: 43.672s
# ---------------------------------------10------------------------------
#
# === Setup ===
# Data splitting: 0.000s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.032s
# Gather results (parallel work): 2.635s
# Result aggregation: 0.026s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.698s
#
# --- Iteration 2 ---
# Submit tasks: 0.034s
# Gather results (parallel work): 2.582s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.648s
#
# --- Iteration 3 ---
# Submit tasks: 0.052s
# Gather results (parallel work): 2.621s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.704s
#
# --- Iteration 4 ---
# Submit tasks: 0.047s
# Gather results (parallel work): 2.716s
# Result aggregation: 0.024s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.794s
#
# --- Iteration 5 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 2.633s
# Result aggregation: 0.027s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.698s
#
# --- Iteration 6 ---
# Submit tasks: 0.026s
# Gather results (parallel work): 2.578s
# Result aggregation: 0.024s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.635s
#
# --- Iteration 7 ---
# Submit tasks: 0.040s
# Gather results (parallel work): 2.575s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.648s
#
# --- Iteration 8 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 2.623s
# Result aggregation: 0.022s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.685s
#
# --- Iteration 9 ---
# Submit tasks: 0.029s
# Gather results (parallel work): 2.621s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.679s
#
# --- Iteration 10 ---
# Submit tasks: 0.037s
# Gather results (parallel work): 2.622s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.689s
#
# --- Iteration 11 ---
# Submit tasks: 0.033s
# Gather results (parallel work): 2.657s
# Result aggregation: 0.027s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.725s
#
# --- Iteration 12 ---
# Submit tasks: 0.030s
# Gather results (parallel work): 2.604s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.666s
#
# --- Iteration 13 ---
# Submit tasks: 0.043s
# Gather results (parallel work): 2.577s
# Result aggregation: 0.029s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.656s
#
# --- Iteration 14 ---
# Submit tasks: 0.037s
# Gather results (parallel work): 2.574s
# Result aggregation: 0.025s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.644s
#
# --- Iteration 15 ---
# Submit tasks: 0.035s
# Gather results (parallel work): 2.678s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.744s
#
# --- Iteration 16 ---
# Submit tasks: 0.031s
# Gather results (parallel work): 2.603s
# Result aggregation: 0.023s
# Centroid update: 0.003s
# Convergence check: 0.004s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 2.666s
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 43.832s
# Number of iterations: 16
#
# Submit times per iteration: ['0.032s', '0.034s', '0.052s', '0.047s', '0.031s', '0.026s', '0.040s', '0.033s', '0.029s', '0.037s', '0.033s', '0.030s', '0.043s', '0.037s', '0.035s', '0.031s']
# Sum submit time: 0.568s
#
# Gather times per iteration: ['2.635s', '2.582s', '2.621s', '2.716s', '2.633s', '2.578s', '2.575s', '2.623s', '2.621s', '2.622s', '2.657s', '2.604s', '2.577s', '2.574s', '2.678s', '2.603s']
# Sum gather time: 41.900s
#
# Sum aggregation time: 0.394s
# Sum centroid update time: 0.050s
# Sum convergence check time: 0.052s
# Sum iteration overhead time: 0.014s
#
# === Time Breakdown ===
# Submit tasks: 0.568s (1.3%)
# Gather (parallel work): 41.900s (97.5%)
# Aggregation: 0.394s (0.9%)
# Centroid updates: 0.050s (0.1%)
# Convergence checks: 0.052s (0.1%)
# Iteration overhead (print, misc): 0.014s (0.0%)
#
# === Verification ===
# Sum of all measured times: 42.979s
# Actual total training time: 43.832s
# Setup time: 0.000s
# Expected total: 42.979s
# Training time = 53.20 seconds
#
# ✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.
#
# 🏃 View run parsl12 at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/5/runs/38944d5a15e94ffcb27f06e1e082d629
# 🧪 View experiment at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/5

# %%
from kmeans_dask import KMeansDistributedDask
import numpy as np
from dask.distributed import Client
import time
import mlflow
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score


# Start MLflow run
with mlflow.start_run(run_name="dask12"):
    # Setup Parsl configuration
    # Disable all parsl logging before loading
    import logging
    # MLflow: log parameters
    mlflow.log_param("n_clusters", 3)
    mlflow.log_param("max_iter", 300)
    mlflow.log_param("num_workers", 12)
    mlflow.log_param("num_folds", 10)
    mlflow.log_param("num_images", len(images_flat))
    num_features = images_flat.shape[1]
    mlflow.log_param("num_features", num_features)

    
    print("Starting Dask Client...")
    client = Client(n_workers=1, threads_per_worker=12)
    dask_time=[]
    for i in range(10):
        print(f'-------------------------------------{i+1}-----------------------------')
        kmeans_dask = KMeansDistributedDask(n_clusters=3, max_iter=300, n_workers=12)
        start = time.time()
        kmeans_dask.fit(images_flat, client)
        end = time.time()
        dask_time.append(end-start)

    training_time = np.mean(dask_time)
    print(f"Training time = {training_time:.2f} seconds")

    # MLflow: log training time
    mlflow.log_metric("avg training time", training_time)

    # Retrieve results from your KMeans class
    centroids = kmeans_dask.cluster_centers_
    num_iterations = kmeans_dask.number_of_iter
    cluster_labels = kmeans_dask.labels_

    # MLflow: Log iteration count
    mlflow.log_metric("iterations", num_iterations)

    # Compute cluster sizes
    unique, counts = np.unique(cluster_labels, return_counts=True)
    cluster_size_dict = {int(k): int(v) for k, v in zip(unique, counts)}

    # MLflow: Log size of each cluster
    for cluster_id, size in cluster_size_dict.items():
        mlflow.log_metric(f"cluster_{cluster_id}_size", size)

    y_pred = kmeans_dask.labels_
    # Get predictions (cluster labels)
    dbi_score = davies_bouldin_score(images_flat, y_pred)
    mlflow.log_metric("davies bouldin score ", dbi_score)
    ch_score = calinski_harabasz_score(images_flat, y_pred)
    mlflow.log_metric("calinski harabasz score ", ch_score)
    score = silhouette_score(images_flat, y_pred)
    mlflow.log_metric("silhouette score ", score)

    

    print("\n✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.\n")
    client.close()
# Out:
# Starting Dask Client...
# -------------------------------------1-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 9.027s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.161s
# Gather results: 4.079s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.002s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.168s
# Gather results: 4.471s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.181s
# Gather results: 4.550s
# Result aggregation: 0.014s
# Centroid update: 0.004s
# Convergence check: 0.002s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.170s
# Gather results: 4.369s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.164s
# Gather results: 4.312s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.172s
# Gather results: 4.414s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.165s
# Gather results: 4.195s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.170s
# Gather results: 4.174s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.188s
# Gather results: 3.877s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.165s
# Gather results: 4.055s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.168s
# Gather results: 4.322s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.162s
# Gather results: 4.112s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.163s
# Gather results: 3.999s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.174s
# Gather results: 3.999s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.177s
# Gather results: 4.027s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.169s
# Gather results: 4.104s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 80.376s
# Number of iterations: 16
#
# Submit times per iteration: ['0.161s', '0.168s', '0.181s', '0.170s', '0.164s', '0.172s', '0.165s', '0.170s', '0.188s', '0.165s', '0.168s', '0.162s', '0.163s', '0.174s', '0.177s', '0.169s']
# Somme submit time: 2.718s
#
# Gather times per iteration: ['4.079s', '4.471s', '4.550s', '4.369s', '4.312s', '4.414s', '4.195s', '4.174s', '3.877s', '4.055s', '4.322s', '4.112s', '3.999s', '3.999s', '4.027s', '4.104s']
# Somme gather time: 67.058s
#
# Somme aggregation time: 0.212s
# Somme centroid update time: 0.048s
# Somme convergence check time: 0.039s
#
# === Time Breakdown ===
# Submit tasks: 2.718s (3.9%)
# Gather (parallel work): 67.058s (95.7%)
# Aggregation: 0.212s (0.3%)
# Centroid updates: 0.048s (0.1%)
# Convergence checks: 0.039s (0.1%)
# -------------------------------------2-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 7.730s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.228s
# Gather results: 3.313s
# Result aggregation: 0.013s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.169s
# Gather results: 4.087s
# Result aggregation: 0.015s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.208s
# Gather results: 4.377s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.167s
# Gather results: 4.393s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.163s
# Gather results: 4.452s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.169s
# Gather results: 4.279s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.170s
# Gather results: 4.154s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.172s
# Gather results: 4.213s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.173s
# Gather results: 3.985s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.165s
# Gather results: 4.130s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.172s
# Gather results: 3.989s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.159s
# Gather results: 3.846s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.176s
# Gather results: 3.836s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.176s
# Gather results: 4.010s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.168s
# Gather results: 4.276s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.169s
# Gather results: 4.373s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 77.520s
# Number of iterations: 16
#
# Submit times per iteration: ['0.228s', '0.169s', '0.208s', '0.167s', '0.163s', '0.169s', '0.170s', '0.172s', '0.173s', '0.165s', '0.172s', '0.159s', '0.176s', '0.176s', '0.168s', '0.169s']
# Somme submit time: 2.803s
#
# Gather times per iteration: ['3.313s', '4.087s', '4.377s', '4.393s', '4.452s', '4.279s', '4.154s', '4.213s', '3.985s', '4.130s', '3.989s', '3.846s', '3.836s', '4.010s', '4.276s', '4.373s']
# Somme gather time: 65.714s
#
# Somme aggregation time: 0.214s
# Somme centroid update time: 0.050s
# Somme convergence check time: 0.040s
#
# === Time Breakdown ===
# Submit tasks: 2.803s (4.1%)
# Gather (parallel work): 65.714s (95.5%)
# Aggregation: 0.214s (0.3%)
# Centroid updates: 0.050s (0.1%)
# Convergence checks: 0.040s (0.1%)
# -------------------------------------3-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 8.091s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.226s
# Gather results: 3.616s
# Result aggregation: 0.014s
# Centroid update: 0.002s
# Convergence check: 0.002s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.169s
# Gather results: 4.065s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.153s
# Gather results: 4.139s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.171s
# Gather results: 4.302s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.182s
# Gather results: 4.244s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.177s
# Gather results: 3.916s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.170s
# Gather results: 3.925s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.169s
# Gather results: 4.131s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.176s
# Gather results: 4.159s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.174s
# Gather results: 4.144s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.173s
# Gather results: 4.256s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.176s
# Gather results: 4.179s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.165s
# Gather results: 4.211s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.194s
# Gather results: 4.007s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.166s
# Gather results: 4.116s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.168s
# Gather results: 4.133s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 77.727s
# Number of iterations: 16
#
# Submit times per iteration: ['0.226s', '0.169s', '0.153s', '0.171s', '0.182s', '0.177s', '0.170s', '0.169s', '0.176s', '0.174s', '0.173s', '0.176s', '0.165s', '0.194s', '0.166s', '0.168s']
# Somme submit time: 2.809s
#
# Gather times per iteration: ['3.616s', '4.065s', '4.139s', '4.302s', '4.244s', '3.916s', '3.925s', '4.131s', '4.159s', '4.144s', '4.256s', '4.179s', '4.211s', '4.007s', '4.116s', '4.133s']
# Somme gather time: 65.542s
#
# Somme aggregation time: 0.210s
# Somme centroid update time: 0.047s
# Somme convergence check time: 0.040s
#
# === Time Breakdown ===
# Submit tasks: 2.809s (4.1%)
# Gather (parallel work): 65.542s (95.5%)
# Aggregation: 0.210s (0.3%)
# Centroid updates: 0.047s (0.1%)
# Convergence checks: 0.040s (0.1%)
# -------------------------------------4-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 8.044s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.235s
# Gather results: 3.277s
# Result aggregation: 0.016s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.227s
# Gather results: 3.864s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.161s
# Gather results: 4.157s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.165s
# Gather results: 3.986s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.209s
# Gather results: 3.992s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.174s
# Gather results: 4.155s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.172s
# Gather results: 4.344s
# Result aggregation: 0.013s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.177s
# Gather results: 4.107s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.181s
# Gather results: 4.187s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.159s
# Gather results: 4.256s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.172s
# Gather results: 4.371s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.173s
# Gather results: 4.406s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.167s
# Gather results: 4.478s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.161s
# Gather results: 4.175s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.168s
# Gather results: 4.509s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.174s
# Gather results: 4.451s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 78.875s
# Number of iterations: 16
#
# Submit times per iteration: ['0.235s', '0.227s', '0.161s', '0.165s', '0.209s', '0.174s', '0.172s', '0.177s', '0.181s', '0.159s', '0.172s', '0.173s', '0.167s', '0.161s', '0.168s', '0.174s']
# Somme submit time: 2.875s
#
# Gather times per iteration: ['3.277s', '3.864s', '4.157s', '3.986s', '3.992s', '4.155s', '4.344s', '4.107s', '4.187s', '4.256s', '4.371s', '4.406s', '4.478s', '4.175s', '4.509s', '4.451s']
# Somme gather time: 66.714s
#
# Somme aggregation time: 0.212s
# Somme centroid update time: 0.049s
# Somme convergence check time: 0.040s
#
# === Time Breakdown ===
# Submit tasks: 2.875s (4.1%)
# Gather (parallel work): 66.714s (95.5%)
# Aggregation: 0.212s (0.3%)
# Centroid updates: 0.049s (0.1%)
# Convergence checks: 0.040s (0.1%)
# -------------------------------------5-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 7.823s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.162s
# Gather results: 3.268s
# Result aggregation: 0.014s
# Centroid update: 0.002s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.179s
# Gather results: 3.712s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.157s
# Gather results: 3.971s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.151s
# Gather results: 4.025s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.174s
# Gather results: 3.947s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.170s
# Gather results: 4.208s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.164s
# Gather results: 4.253s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.180s
# Gather results: 4.415s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.168s
# Gather results: 4.304s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.170s
# Gather results: 4.272s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.171s
# Gather results: 4.247s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.189s
# Gather results: 4.300s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.167s
# Gather results: 4.182s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.180s
# Gather results: 4.091s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.158s
# Gather results: 4.027s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.167s
# Gather results: 4.125s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 77.056s
# Number of iterations: 16
#
# Submit times per iteration: ['0.162s', '0.179s', '0.157s', '0.151s', '0.174s', '0.170s', '0.164s', '0.180s', '0.168s', '0.170s', '0.171s', '0.189s', '0.167s', '0.180s', '0.158s', '0.167s']
# Somme submit time: 2.707s
#
# Gather times per iteration: ['3.268s', '3.712s', '3.971s', '4.025s', '3.947s', '4.208s', '4.253s', '4.415s', '4.304s', '4.272s', '4.247s', '4.300s', '4.182s', '4.091s', '4.027s', '4.125s']
# Somme gather time: 65.347s
#
# Somme aggregation time: 0.208s
# Somme centroid update time: 0.048s
# Somme convergence check time: 0.040s
#
# === Time Breakdown ===
# Submit tasks: 2.707s (4.0%)
# Gather (parallel work): 65.347s (95.6%)
# Aggregation: 0.208s (0.3%)
# Centroid updates: 0.048s (0.1%)
# Convergence checks: 0.040s (0.1%)
# -------------------------------------6-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 8.058s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.227s
# Gather results: 3.046s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.002s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.181s
# Gather results: 3.756s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.164s
# Gather results: 3.760s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.162s
# Gather results: 3.938s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.170s
# Gather results: 3.926s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.172s
# Gather results: 3.979s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.179s
# Gather results: 4.464s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.175s
# Gather results: 3.894s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.170s
# Gather results: 4.134s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.159s
# Gather results: 4.172s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.172s
# Gather results: 4.135s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.170s
# Gather results: 3.990s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.158s
# Gather results: 3.908s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.173s
# Gather results: 3.767s
# Result aggregation: 0.013s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.174s
# Gather results: 3.953s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.166s
# Gather results: 4.005s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 74.718s
# Number of iterations: 16
#
# Submit times per iteration: ['0.227s', '0.181s', '0.164s', '0.162s', '0.170s', '0.172s', '0.179s', '0.175s', '0.170s', '0.159s', '0.172s', '0.170s', '0.158s', '0.173s', '0.174s', '0.166s']
# Somme submit time: 2.774s
#
# Gather times per iteration: ['3.046s', '3.756s', '3.760s', '3.938s', '3.926s', '3.979s', '4.464s', '3.894s', '4.134s', '4.172s', '4.135s', '3.990s', '3.908s', '3.767s', '3.953s', '4.005s']
# Somme gather time: 62.828s
#
# Somme aggregation time: 0.213s
# Somme centroid update time: 0.048s
# Somme convergence check time: 0.041s
#
# === Time Breakdown ===
# Submit tasks: 2.774s (4.2%)
# Gather (parallel work): 62.828s (95.3%)
# Aggregation: 0.213s (0.3%)
# Centroid updates: 0.048s (0.1%)
# Convergence checks: 0.041s (0.1%)
# -------------------------------------7-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 8.322s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.235s
# Gather results: 3.287s
# Result aggregation: 0.016s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.230s
# Gather results: 4.189s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.181s
# Gather results: 4.259s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.168s
# Gather results: 4.309s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.195s
# Gather results: 4.162s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.173s
# Gather results: 4.507s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.165s
# Gather results: 4.282s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.165s
# Gather results: 4.247s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.179s
# Gather results: 4.318s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.167s
# Gather results: 4.486s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.180s
# Gather results: 4.108s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.173s
# Gather results: 4.031s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.165s
# Gather results: 4.136s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.171s
# Gather results: 3.929s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.173s
# Gather results: 4.004s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.166s
# Gather results: 4.241s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 78.913s
# Number of iterations: 16
#
# Submit times per iteration: ['0.235s', '0.230s', '0.181s', '0.168s', '0.195s', '0.173s', '0.165s', '0.165s', '0.179s', '0.167s', '0.180s', '0.173s', '0.165s', '0.171s', '0.173s', '0.166s']
# Somme submit time: 2.887s
#
# Gather times per iteration: ['3.287s', '4.189s', '4.259s', '4.309s', '4.162s', '4.507s', '4.282s', '4.247s', '4.318s', '4.486s', '4.108s', '4.031s', '4.136s', '3.929s', '4.004s', '4.241s']
# Somme gather time: 66.494s
#
# Somme aggregation time: 0.214s
# Somme centroid update time: 0.047s
# Somme convergence check time: 0.041s
#
# === Time Breakdown ===
# Submit tasks: 2.887s (4.1%)
# Gather (parallel work): 66.494s (95.4%)
# Aggregation: 0.214s (0.3%)
# Centroid updates: 0.047s (0.1%)
# Convergence checks: 0.041s (0.1%)
# -------------------------------------8-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 8.057s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.232s
# Gather results: 3.476s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.002s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.166s
# Gather results: 4.144s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.166s
# Gather results: 4.289s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.171s
# Gather results: 4.228s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.164s
# Gather results: 4.421s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.164s
# Gather results: 4.239s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.161s
# Gather results: 4.001s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.177s
# Gather results: 3.926s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.158s
# Gather results: 4.293s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.169s
# Gather results: 4.177s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.162s
# Gather results: 3.964s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.166s
# Gather results: 4.303s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.171s
# Gather results: 4.059s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.172s
# Gather results: 4.057s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.189s
# Gather results: 3.923s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.164s
# Gather results: 4.062s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 77.421s
# Number of iterations: 16
#
# Submit times per iteration: ['0.232s', '0.166s', '0.166s', '0.171s', '0.164s', '0.164s', '0.161s', '0.177s', '0.158s', '0.169s', '0.162s', '0.166s', '0.171s', '0.172s', '0.189s', '0.164s']
# Somme submit time: 2.752s
#
# Gather times per iteration: ['3.476s', '4.144s', '4.289s', '4.228s', '4.421s', '4.239s', '4.001s', '3.926s', '4.293s', '4.177s', '3.964s', '4.303s', '4.059s', '4.057s', '3.923s', '4.062s']
# Somme gather time: 65.564s
#
# Somme aggregation time: 0.211s
# Somme centroid update time: 0.047s
# Somme convergence check time: 0.039s
#
# === Time Breakdown ===
# Submit tasks: 2.752s (4.0%)
# Gather (parallel work): 65.564s (95.6%)
# Aggregation: 0.211s (0.3%)
# Centroid updates: 0.047s (0.1%)
# Convergence checks: 0.039s (0.1%)
# -------------------------------------9-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 8.208s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.234s
# Gather results: 2.964s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.002s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.159s
# Gather results: 4.043s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.185s
# Gather results: 4.200s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.164s
# Gather results: 4.157s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.202s
# Gather results: 4.266s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.179s
# Gather results: 4.402s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.166s
# Gather results: 4.334s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.164s
# Gather results: 4.270s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.167s
# Gather results: 4.263s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.165s
# Gather results: 4.163s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.181s
# Gather results: 4.201s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.178s
# Gather results: 4.118s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.166s
# Gather results: 4.009s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.179s
# Gather results: 4.133s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.183s
# Gather results: 4.249s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.181s
# Gather results: 4.049s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 77.954s
# Number of iterations: 16
#
# Submit times per iteration: ['0.234s', '0.159s', '0.185s', '0.164s', '0.202s', '0.179s', '0.166s', '0.164s', '0.167s', '0.165s', '0.181s', '0.178s', '0.166s', '0.179s', '0.183s', '0.181s']
# Somme submit time: 2.851s
#
# Gather times per iteration: ['2.964s', '4.043s', '4.200s', '4.157s', '4.266s', '4.402s', '4.334s', '4.270s', '4.263s', '4.163s', '4.201s', '4.118s', '4.009s', '4.133s', '4.249s', '4.049s']
# Somme gather time: 65.821s
#
# Somme aggregation time: 0.212s
# Somme centroid update time: 0.048s
# Somme convergence check time: 0.042s
#
# === Time Breakdown ===
# Submit tasks: 2.851s (4.1%)
# Gather (parallel work): 65.821s (95.4%)
# Aggregation: 0.212s (0.3%)
# Centroid updates: 0.048s (0.1%)
# Convergence checks: 0.042s (0.1%)
# -------------------------------------10-----------------------------
#
# === Setup ===
# Data splitting: 0.000s
# Scatter to workers: 8.173s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Submit tasks: 0.232s
# Gather results: 3.067s
# Result aggregation: 0.013s
# Centroid update: 0.002s
# Convergence check: 0.002s | Center shift: 323.257310
#
# --- Iteration 2 ---
# Submit tasks: 0.163s
# Gather results: 3.798s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055547
#
# --- Iteration 3 ---
# Submit tasks: 0.168s
# Gather results: 3.950s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500586
#
# --- Iteration 4 ---
# Submit tasks: 0.167s
# Gather results: 4.082s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
#
# --- Iteration 5 ---
# Submit tasks: 0.166s
# Gather results: 4.242s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
#
# --- Iteration 6 ---
# Submit tasks: 0.169s
# Gather results: 4.241s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
#
# --- Iteration 7 ---
# Submit tasks: 0.160s
# Gather results: 4.073s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
#
# --- Iteration 8 ---
# Submit tasks: 0.171s
# Gather results: 4.250s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
#
# --- Iteration 9 ---
# Submit tasks: 0.159s
# Gather results: 4.152s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
#
# --- Iteration 10 ---
# Submit tasks: 0.160s
# Gather results: 4.143s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
#
# --- Iteration 11 ---
# Submit tasks: 0.163s
# Gather results: 4.088s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
#
# --- Iteration 12 ---
# Submit tasks: 0.161s
# Gather results: 4.071s
# Result aggregation: 0.014s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147711
#
# --- Iteration 13 ---
# Submit tasks: 0.162s
# Gather results: 4.259s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
#
# --- Iteration 14 ---
# Submit tasks: 0.169s
# Gather results: 4.290s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
#
# --- Iteration 15 ---
# Submit tasks: 0.163s
# Gather results: 4.300s
# Result aggregation: 0.013s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.167428
#
# --- Iteration 16 ---
# Submit tasks: 0.167s
# Gather results: 4.196s
# Result aggregation: 0.012s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
#
# ✓ Converged after 16 iterations
#
# === Training Summary ===
# Total training time: 77.202s
# Number of iterations: 16
#
# Submit times per iteration: ['0.232s', '0.163s', '0.168s', '0.167s', '0.166s', '0.169s', '0.160s', '0.171s', '0.159s', '0.160s', '0.163s', '0.161s', '0.162s', '0.169s', '0.163s', '0.167s']
# Somme submit time: 2.700s
#
# Gather times per iteration: ['3.067s', '3.798s', '3.950s', '4.082s', '4.242s', '4.241s', '4.073s', '4.250s', '4.152s', '4.143s', '4.088s', '4.071s', '4.259s', '4.290s', '4.300s', '4.196s']
# Somme gather time: 65.203s
#
# Somme aggregation time: 0.211s
# Somme centroid update time: 0.048s
# Somme convergence check time: 0.042s
#
# === Time Breakdown ===
# Submit tasks: 2.700s (4.0%)
# Gather (parallel work): 65.203s (95.6%)
# Aggregation: 0.211s (0.3%)
# Centroid updates: 0.048s (0.1%)
# Convergence checks: 0.042s (0.1%)
# Training time = 77.79 seconds
#
# ✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.
#
# 🏃 View run dask12 at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/5/runs/7adedf9eeda541ffaa493722929c9b67
# 🧪 View experiment at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/5

# %%
from kmeans_multiprocessing import KMeansMultiprocessing
import mlflow.pyfunc
import mlflow
import numpy as np
from multiprocessing import Pool, cpu_count, shared_memory
import os
import ctypes
import time
from sklearn.metrics import calinski_harabasz_score
from sklearn.metrics import silhouette_score
from sklearn.metrics import davies_bouldin_score

# Start MLflow run
with mlflow.start_run(run_name="mult6"):
    # Setup Parsl configuration
    # Disable all parsl logging before loading
    import logging
    # MLflow: log parameters
    mlflow.log_param("n_clusters", 3)
    mlflow.log_param("max_iter", 300)
    mlflow.log_param("num_workers", 6)
    mlflow.log_param("num_folds", 10)
    mlflow.log_param("num_images", len(images_flat))
    num_features = images_flat.shape[1]
    mlflow.log_param("num_features", num_features)
    mult_time =[]
    for i in range(10):
        print(f"------------------------------------------------------------------{i+1}------------------------------------------------------------")
        debut = time.time()
        kmeans_mult = KMeansMultiprocessing(n_clusters= 3, max_iter=300, n_workers=6, use_shared_memory=True)
        kmeans_mult.fit(images_flat)
        fin = time.time()
        mult_time.append(fin-debut)

    training_time = np.mean(mult_time)
    print(f"Training time = {training_time:.2f} seconds")

    # MLflow: log training time
    mlflow.log_metric("avg training time", training_time)

    # Retrieve results from your KMeans class
    centroids = kmeans_mult.cluster_centers_
    num_iterations = kmeans_mult.number_of_iter
    cluster_labels = kmeans_mult.labels_

    # MLflow: Log iteration count
    mlflow.log_metric("iterations", num_iterations)

    # Compute cluster sizes
    unique, counts = np.unique(cluster_labels, return_counts=True)
    cluster_size_dict = {int(k): int(v) for k, v in zip(unique, counts)}

    # MLflow: Log size of each cluster
    for cluster_id, size in cluster_size_dict.items():
        mlflow.log_metric(f"cluster_{cluster_id}_size", size)

    y_pred = kmeans_mult.labels_
    # Get predictions (cluster labels)
    dbi_score = davies_bouldin_score(images_flat, y_pred)
    mlflow.log_metric("davies bouldin score ", dbi_score)
    ch_score = calinski_harabasz_score(images_flat, y_pred)
    mlflow.log_metric("calinski harabasz score ", ch_score)
    score = silhouette_score(images_flat, y_pred)
    mlflow.log_metric("silhouette score ", score)
    

    print("\n✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.\n")
# Out:
# ------------------------------------------------------------------1------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.708s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.288s
# Result aggregation: 0.012s
# Centroid update: 0.005s
# Convergence check: 0.007s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.313s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.499s
# Result aggregation: 0.021s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.528s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.166s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.180s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.056s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.074s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.099s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.118s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.061s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.075s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.021s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.039s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.040s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.055s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 2.994s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.009s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.035s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.006s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.056s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.333s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.352s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.056s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.070s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 2.995s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.010s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.125s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.142s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.143s
# Result aggregation: 0.009s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.160s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.313s
# Result aggregation: 0.009s
# Centroid update: 0.005s
# Convergence check: 0.004s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.332s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.381s
#
# === Training Summary ===
# Total training time: 53.806s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.288s', '3.499s', '3.166s', '3.056s', '3.099s', '3.061s', '3.021s', '3.040s', '2.994s', '3.035s', '3.333s', '3.056s', '2.995s', '3.125s', '3.143s', '3.313s']
# Sum map time: 50.224s
#
# Sum aggregation time: 0.155s
# Sum centroid update time: 0.060s
# Sum convergence check time: 0.060s
# Sum iteration overhead time: 0.014s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 50.224s (99.4%)
# Aggregation: 0.155s (0.3%)
# Centroid updates: 0.060s (0.1%)
# Convergence checks: 0.060s (0.1%)
# Iteration overhead (print, misc): 0.014s (0.0%)
#
# === Verification ===
# Sum of all measured times: 50.514s
# Actual total training time: 53.806s
# Setup + cleanup time: 3.089s
# Expected total: 53.603s
# ------------------------------------------------------------------2------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.804s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.226s
# Result aggregation: 0.014s
# Centroid update: 0.007s
# Convergence check: 0.006s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.254s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.114s
# Result aggregation: 0.016s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.137s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.242s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.256s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.241s
# Result aggregation: 0.010s
# Centroid update: 0.005s
# Convergence check: 0.006s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.264s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.188s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.203s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.269s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.284s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.140s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.159s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.091s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.110s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.200s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.218s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.282s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.297s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.171s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.190s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.097s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.115s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.181s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.198s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.253s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.266s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.139s
# Result aggregation: 0.008s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.156s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.328s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.342s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.536s
#
# === Training Summary ===
# Total training time: 55.025s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.226s', '3.114s', '3.242s', '3.241s', '3.188s', '3.269s', '3.140s', '3.091s', '3.200s', '3.282s', '3.171s', '3.097s', '3.181s', '3.253s', '3.139s', '3.328s']
# Sum map time: 51.163s
#
# Sum aggregation time: 0.149s
# Sum centroid update time: 0.063s
# Sum convergence check time: 0.060s
# Sum iteration overhead time: 0.014s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 51.163s (99.4%)
# Aggregation: 0.149s (0.3%)
# Centroid updates: 0.063s (0.1%)
# Convergence checks: 0.060s (0.1%)
# Iteration overhead (print, misc): 0.014s (0.0%)
#
# === Verification ===
# Sum of all measured times: 51.449s
# Actual total training time: 55.025s
# Setup + cleanup time: 3.342s
# Expected total: 54.791s
# ------------------------------------------------------------------3------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 3.491s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.299s
# Result aggregation: 0.014s
# Centroid update: 0.007s
# Convergence check: 0.007s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.330s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.388s
# Result aggregation: 0.017s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.411s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.415s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.433s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.321s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.335s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.374s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.388s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.443s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.458s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.562s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.577s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.422s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.435s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.434s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.452s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.936s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.953s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.432s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.447s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.299s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.312s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.588s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.602s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.373s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.388s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.576s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.590s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.447s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.465s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.509s
#
# === Training Summary ===
# Total training time: 59.765s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.299s', '3.388s', '3.415s', '3.321s', '3.374s', '3.443s', '3.562s', '3.422s', '3.434s', '3.936s', '3.432s', '3.299s', '3.588s', '3.373s', '3.576s', '3.447s']
# Sum map time: 55.308s
#
# Sum aggregation time: 0.144s
# Sum centroid update time: 0.057s
# Sum convergence check time: 0.054s
# Sum iteration overhead time: 0.012s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 55.308s (99.5%)
# Aggregation: 0.144s (0.3%)
# Centroid updates: 0.057s (0.1%)
# Convergence checks: 0.054s (0.1%)
# Iteration overhead (print, misc): 0.012s (0.0%)
#
# === Verification ===
# Sum of all measured times: 55.575s
# Actual total training time: 59.765s
# Setup + cleanup time: 4.002s
# Expected total: 59.577s
# ------------------------------------------------------------------4------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.833s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.536s
# Result aggregation: 0.012s
# Centroid update: 0.005s
# Convergence check: 0.005s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.559s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.413s
# Result aggregation: 0.020s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.441s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.401s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.419s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.396s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.414s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.560s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.575s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.266s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.280s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.380s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.006s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.397s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.264s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.282s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.598s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.614s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.464s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.478s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.812s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.829s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.768s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.782s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.838s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.851s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.660s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.677s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.621s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.634s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.635s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.652s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.391s
#
# === Training Summary ===
# Total training time: 60.319s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.536s', '3.413s', '3.401s', '3.396s', '3.560s', '3.266s', '3.380s', '3.264s', '3.598s', '3.464s', '3.812s', '3.768s', '3.838s', '3.660s', '3.621s', '3.635s']
# Sum map time: 56.611s
#
# Sum aggregation time: 0.146s
# Sum centroid update time: 0.058s
# Sum convergence check time: 0.056s
# Sum iteration overhead time: 0.013s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 56.611s (99.5%)
# Aggregation: 0.146s (0.3%)
# Centroid updates: 0.058s (0.1%)
# Convergence checks: 0.056s (0.1%)
# Iteration overhead (print, misc): 0.013s (0.0%)
#
# === Verification ===
# Sum of all measured times: 56.885s
# Actual total training time: 60.319s
# Setup + cleanup time: 3.225s
# Expected total: 60.110s
# ------------------------------------------------------------------5------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.814s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.647s
# Result aggregation: 0.014s
# Centroid update: 0.007s
# Convergence check: 0.006s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.675s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.440s
# Result aggregation: 0.016s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.462s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.501s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.516s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.337s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.355s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.394s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.407s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.382s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.400s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.607s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.621s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.397s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.411s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.495s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.509s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.722s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.740s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.447s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.461s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.454s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.469s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.533s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.552s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.613s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.627s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.495s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.510s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.381s
# Result aggregation: 0.009s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.397s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.549s
#
# === Training Summary ===
# Total training time: 59.697s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.647s', '3.440s', '3.501s', '3.337s', '3.394s', '3.382s', '3.607s', '3.397s', '3.495s', '3.722s', '3.447s', '3.454s', '3.533s', '3.613s', '3.495s', '3.381s']
# Sum map time: 55.843s
#
# Sum aggregation time: 0.144s
# Sum centroid update time: 0.056s
# Sum convergence check time: 0.053s
# Sum iteration overhead time: 0.014s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 55.843s (99.5%)
# Aggregation: 0.144s (0.3%)
# Centroid updates: 0.056s (0.1%)
# Convergence checks: 0.053s (0.1%)
# Iteration overhead (print, misc): 0.014s (0.0%)
#
# === Verification ===
# Sum of all measured times: 56.111s
# Actual total training time: 59.697s
# Setup + cleanup time: 3.364s
# Expected total: 59.474s
# ------------------------------------------------------------------6------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 3.000s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.307s
# Result aggregation: 0.011s
# Centroid update: 0.005s
# Convergence check: 0.005s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.329s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.375s
# Result aggregation: 0.020s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.403s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.470s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.488s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.432s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.450s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.408s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.423s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.540s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.555s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.401s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.416s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.632s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.650s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.689s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.707s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.605s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.623s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.545s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.559s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.633s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.652s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.601s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.616s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.688s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.705s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.543s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.561s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.992s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.012s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.523s
#
# === Training Summary ===
# Total training time: 60.916s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.307s', '3.375s', '3.470s', '3.432s', '3.408s', '3.540s', '3.401s', '3.632s', '3.689s', '3.605s', '3.545s', '3.633s', '3.601s', '3.688s', '3.543s', '3.992s']
# Sum map time: 56.860s
#
# Sum aggregation time: 0.156s
# Sum centroid update time: 0.061s
# Sum convergence check time: 0.057s
# Sum iteration overhead time: 0.014s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 56.860s (99.5%)
# Aggregation: 0.156s (0.3%)
# Centroid updates: 0.061s (0.1%)
# Convergence checks: 0.057s (0.1%)
# Iteration overhead (print, misc): 0.014s (0.0%)
#
# === Verification ===
# Sum of all measured times: 57.149s
# Actual total training time: 60.916s
# Setup + cleanup time: 3.524s
# Expected total: 60.673s
# ------------------------------------------------------------------7------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.779s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.681s
# Result aggregation: 0.014s
# Centroid update: 0.007s
# Convergence check: 0.006s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.709s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.920s
# Result aggregation: 0.016s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.942s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 4.004s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 4.018s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.884s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.899s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.798s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.811s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.677s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.691s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.663s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.680s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.709s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.727s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.670s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.690s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.606s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.620s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.692s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.709s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.524s
# Result aggregation: 0.008s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.541s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.573s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.588s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.784s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.802s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.632s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.646s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.590s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.604s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.389s
#
# === Training Summary ===
# Total training time: 63.079s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.681s', '3.920s', '4.004s', '3.884s', '3.798s', '3.677s', '3.663s', '3.709s', '3.670s', '3.606s', '3.692s', '3.524s', '3.573s', '3.784s', '3.632s', '3.590s']
# Sum map time: 59.405s
#
# Sum aggregation time: 0.146s
# Sum centroid update time: 0.058s
# Sum convergence check time: 0.055s
# Sum iteration overhead time: 0.013s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 59.405s (99.5%)
# Aggregation: 0.146s (0.2%)
# Centroid updates: 0.058s (0.1%)
# Convergence checks: 0.055s (0.1%)
# Iteration overhead (print, misc): 0.013s (0.0%)
#
# === Verification ===
# Sum of all measured times: 59.678s
# Actual total training time: 63.079s
# Setup + cleanup time: 3.169s
# Expected total: 62.847s
# ------------------------------------------------------------------8------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.798s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.541s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.560s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.672s
# Result aggregation: 0.018s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.697s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.440s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.005s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.456s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.575s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.594s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.358s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.376s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.425s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.442s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.431s
# Result aggregation: 0.008s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.447s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.684s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.697s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.524s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.538s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.519s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.534s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.726s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.743s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.584s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.598s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.768s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.783s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.784s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.802s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.709s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.727s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.606s
# Result aggregation: 0.010s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.624s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.528s
#
# === Training Summary ===
# Total training time: 61.196s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.541s', '3.672s', '3.440s', '3.575s', '3.358s', '3.425s', '3.431s', '3.684s', '3.524s', '3.519s', '3.726s', '3.584s', '3.768s', '3.784s', '3.709s', '3.606s']
# Sum map time: 57.347s
#
# Sum aggregation time: 0.147s
# Sum centroid update time: 0.058s
# Sum convergence check time: 0.053s
# Sum iteration overhead time: 0.013s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 57.347s (99.5%)
# Aggregation: 0.147s (0.3%)
# Centroid updates: 0.058s (0.1%)
# Convergence checks: 0.053s (0.1%)
# Iteration overhead (print, misc): 0.013s (0.0%)
#
# === Verification ===
# Sum of all measured times: 57.619s
# Actual total training time: 61.196s
# Setup + cleanup time: 3.327s
# Expected total: 60.946s
# ------------------------------------------------------------------9------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.953s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.508s
# Result aggregation: 0.014s
# Centroid update: 0.006s
# Convergence check: 0.005s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.536s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.593s
# Result aggregation: 0.019s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.619s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.608s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.625s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.761s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.777s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.709s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.726s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.717s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.731s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.504s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.520s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.413s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.428s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.649s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.663s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.374s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.388s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.459s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.477s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.455s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.470s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.376s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.390s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.631s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.645s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.539s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.005s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.555s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.493s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.508s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.540s
#
# === Training Summary ===
# Total training time: 60.805s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.508s', '3.593s', '3.608s', '3.761s', '3.709s', '3.717s', '3.504s', '3.413s', '3.649s', '3.374s', '3.459s', '3.455s', '3.376s', '3.631s', '3.539s', '3.493s']
# Sum map time: 56.790s
#
# Sum aggregation time: 0.146s
# Sum centroid update time: 0.056s
# Sum convergence check time: 0.052s
# Sum iteration overhead time: 0.013s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 56.790s (99.5%)
# Aggregation: 0.146s (0.3%)
# Centroid updates: 0.056s (0.1%)
# Convergence checks: 0.052s (0.1%)
# Iteration overhead (print, misc): 0.013s (0.0%)
#
# === Verification ===
# Sum of all measured times: 57.058s
# Actual total training time: 60.805s
# Setup + cleanup time: 3.494s
# Expected total: 60.552s
# ------------------------------------------------------------------10------------------------------------------------------------
#
# === Setup ===
# Shared memory creation and data copy: 2.928s
# Chunk boundary calculation: 0.001s
#
# === Training Started ===
#
# --- Iteration 1 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.546s
# Result aggregation: 0.011s
# Centroid update: 0.005s
# Convergence check: 0.004s | Center shift: 323.257322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.566s
#
# --- Iteration 2 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.552s
# Result aggregation: 0.020s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 77.055546
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.580s
#
# --- Iteration 3 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.493s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 18.500580
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.506s
#
# --- Iteration 4 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.427s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 5.501034
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.441s
#
# --- Iteration 5 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.572s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.004s | Center shift: 2.195045
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.589s
#
# --- Iteration 6 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.573s
# Result aggregation: 0.008s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.987440
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.589s
#
# --- Iteration 7 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.519s
# Result aggregation: 0.008s
# Centroid update: 0.004s
# Convergence check: 0.006s | Center shift: 0.720022
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.538s
#
# --- Iteration 8 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.406s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.485594
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.420s
#
# --- Iteration 9 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.648s
# Result aggregation: 0.013s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.503888
# Iteration overhead (print, misc): 0.002s
# Total iteration time: 3.670s
#
# --- Iteration 10 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.552s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.570322
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.566s
#
# --- Iteration 11 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.541s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.002s | Center shift: 0.540232
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.554s
#
# --- Iteration 12 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.851s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.147712
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.866s
#
# --- Iteration 13 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.543s
# Result aggregation: 0.009s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.155790
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.560s
#
# --- Iteration 14 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.579s
# Result aggregation: 0.008s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.136633
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.594s
#
# --- Iteration 15 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.702s
# Result aggregation: 0.007s
# Centroid update: 0.003s
# Convergence check: 0.003s | Center shift: 0.167428
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.716s
#
# --- Iteration 16 ---
# Arguments preparation: 0.000s
# Parallel computation (pool.map): 3.610s
# Result aggregation: 0.008s
# Centroid update: 0.004s
# Convergence check: 0.003s | Center shift: 0.000000
# Iteration overhead (print, misc): 0.001s
# Total iteration time: 3.626s
#
# ✓ Converged after 16 iterations
#
# Shared memory cleanup: 0.544s
#
# === Training Summary ===
# Total training time: 61.100s
# Number of iterations: 16
#
# Arguments prep times per iteration: ['0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s', '0.000s']
# Sum args prep time: 0.001s
#
# Map times per iteration: ['3.546s', '3.552s', '3.493s', '3.427s', '3.572s', '3.573s', '3.519s', '3.406s', '3.648s', '3.552s', '3.541s', '3.851s', '3.543s', '3.579s', '3.702s', '3.610s']
# Sum map time: 57.114s
#
# Sum aggregation time: 0.143s
# Sum centroid update time: 0.057s
# Sum convergence check time: 0.053s
# Sum iteration overhead time: 0.013s
#
# === Time Breakdown ===
# Arguments preparation: 0.001s (0.0%)
# Parallel computation: 57.114s (99.5%)
# Aggregation: 0.143s (0.2%)
# Centroid updates: 0.057s (0.1%)
# Convergence checks: 0.053s (0.1%)
# Iteration overhead (print, misc): 0.013s (0.0%)
#
# === Verification ===
# Sum of all measured times: 57.380s
# Actual total training time: 61.100s
# Setup + cleanup time: 3.472s
# Expected total: 60.852s
# Training time = 60.60 seconds
#
# ✓ Logged centroids, iterations, and cluster sizes to MLflow successfully.
#
# 🏃 View run mult6 at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/5/runs/ab2d6549cd1b478f94a5bd954de91e9a
# 🧪 View experiment at: https://dagshub.com/emnaaS/kmeans_repo.mlflow/#/experiments/5

# %%
# !python --version
# Out:
# Python 3.13.5
